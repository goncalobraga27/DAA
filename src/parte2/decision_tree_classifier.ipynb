# %% [markdown]
# ## Modelo criado para a competição da 2ºFase do trabalho da UC de Dados e Aprendizagem Automática

# %% [markdown]
# ### OBJETIVO -  PREVER A quantidade de energia injectada na rede eléctrica QUE SE ENCONTRA NA COLUNA Injeção na rede (kWh) DO DATASET DE ENERGIA

# %% [markdown]
# ### Modelo utilizado - Decision Tree Classifier

# %% [markdown]
# ### Imports de bibliotecas necessárias para desenvolver o modelo

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# ### Leitura do dataset que contêm os dados globais

# %%
df = pd.read_csv('../../datasets/parte2/treino/datasetGlobal.csv', na_filter= False )
df_test = pd.read_csv('../../datasets/parte2/teste/datasetGlobal.csv')

# %% [markdown]
# ### Criação da variavel que queremos prever

# %%
x = df.drop('Injeção na rede (kWh)', axis = 1)
y = df['Injeção na rede (kWh)']

# %% [markdown]
# ### Criação do modelo de Decision Tree Classifier

# %%
param_grid = {
    'criterion': ['gini', 'entropy','ratio'],
    'max_depth': [5,7,9,11,13,15],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
}
clf = DecisionTreeClassifier(random_state= 2023)

# %% [markdown]
# ### Treino do modelo

# %%
# Use GridSearchCV para encontrar os melhores hiperparâmetros
grid_search = GridSearchCV(estimator=clf, param_grid=param_grid,refit=True, verbose=2)
grid_search.fit(x, y)

#descobriu os melhores parametros

clf = grid_search.best_estimator_
# Out:
# Fitting 5 folds for each of 162 candidates, totalling 810 fits
# [CV] END criterion=gini, max_depth=5, min_samples_leaf=1, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=5, min_samples_leaf=1, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=5, min_samples_leaf=1, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=5, min_samples_leaf=1, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=5, min_samples_leaf=1, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=5, min_samples_leaf=1, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=5, min_samples_leaf=1, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=5, min_samples_leaf=1, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=5, min_samples_leaf=1, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=5, min_samples_leaf=1, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=5, min_samples_leaf=1, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=5, min_samples_leaf=1, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=5, min_samples_leaf=1, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=5, min_samples_leaf=1, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=5, min_samples_leaf=1, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=5, min_samples_leaf=2, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=5, min_samples_leaf=2, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=5, min_samples_leaf=2, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=5, min_samples_leaf=2, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=5, min_samples_leaf=2, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=5, min_samples_leaf=2, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=5, min_samples_leaf=2, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=5, min_samples_leaf=2, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=5, min_samples_leaf=2, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=5, min_samples_leaf=2, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=5, min_samples_leaf=2, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=5, min_samples_leaf=2, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=5, min_samples_leaf=2, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=5, min_samples_leaf=2, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=5, min_samples_leaf=2, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=5, min_samples_leaf=4, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=5, min_samples_leaf=4, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=5, min_samples_leaf=4, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=5, min_samples_leaf=4, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=5, min_samples_leaf=4, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=5, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=5, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=5, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=5, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=5, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=5, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=5, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=5, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=5, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=5, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=7, min_samples_leaf=1, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=7, min_samples_leaf=1, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=7, min_samples_leaf=1, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=7, min_samples_leaf=1, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=7, min_samples_leaf=1, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=7, min_samples_leaf=1, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=7, min_samples_leaf=1, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=7, min_samples_leaf=1, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=7, min_samples_leaf=1, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=7, min_samples_leaf=1, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=7, min_samples_leaf=1, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=7, min_samples_leaf=1, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=7, min_samples_leaf=1, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=7, min_samples_leaf=1, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=7, min_samples_leaf=1, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=7, min_samples_leaf=2, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=7, min_samples_leaf=2, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=7, min_samples_leaf=2, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=7, min_samples_leaf=2, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=7, min_samples_leaf=2, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=7, min_samples_leaf=2, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=7, min_samples_leaf=2, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=7, min_samples_leaf=2, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=7, min_samples_leaf=2, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=7, min_samples_leaf=2, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=7, min_samples_leaf=2, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=7, min_samples_leaf=2, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=7, min_samples_leaf=2, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=7, min_samples_leaf=2, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=7, min_samples_leaf=2, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=7, min_samples_leaf=4, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=7, min_samples_leaf=4, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=7, min_samples_leaf=4, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=7, min_samples_leaf=4, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=7, min_samples_leaf=4, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=7, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=7, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=7, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=7, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=7, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=7, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=7, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=7, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=7, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=7, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=9, min_samples_leaf=1, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=9, min_samples_leaf=1, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=9, min_samples_leaf=1, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=9, min_samples_leaf=1, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=9, min_samples_leaf=1, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=9, min_samples_leaf=1, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=9, min_samples_leaf=1, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=9, min_samples_leaf=1, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=9, min_samples_leaf=1, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=9, min_samples_leaf=1, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=9, min_samples_leaf=1, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=9, min_samples_leaf=1, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=9, min_samples_leaf=1, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=9, min_samples_leaf=1, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=9, min_samples_leaf=1, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=9, min_samples_leaf=2, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=9, min_samples_leaf=2, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=9, min_samples_leaf=2, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=9, min_samples_leaf=2, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=9, min_samples_leaf=2, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=9, min_samples_leaf=2, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=9, min_samples_leaf=2, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=9, min_samples_leaf=2, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=9, min_samples_leaf=2, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=9, min_samples_leaf=2, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=9, min_samples_leaf=2, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=9, min_samples_leaf=2, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=9, min_samples_leaf=2, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=9, min_samples_leaf=2, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=9, min_samples_leaf=2, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=9, min_samples_leaf=4, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=9, min_samples_leaf=4, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=9, min_samples_leaf=4, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=9, min_samples_leaf=4, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=9, min_samples_leaf=4, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=9, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=9, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=9, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=9, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=9, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=9, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=9, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=9, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=9, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=9, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=11, min_samples_leaf=1, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=11, min_samples_leaf=1, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=11, min_samples_leaf=1, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=11, min_samples_leaf=1, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=11, min_samples_leaf=1, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=11, min_samples_leaf=1, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=11, min_samples_leaf=1, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=11, min_samples_leaf=1, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=11, min_samples_leaf=1, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=11, min_samples_leaf=1, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=11, min_samples_leaf=1, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=11, min_samples_leaf=1, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=11, min_samples_leaf=1, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=11, min_samples_leaf=1, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=11, min_samples_leaf=1, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=11, min_samples_leaf=2, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=11, min_samples_leaf=2, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=11, min_samples_leaf=2, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=11, min_samples_leaf=2, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=11, min_samples_leaf=2, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=11, min_samples_leaf=2, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=11, min_samples_leaf=2, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=11, min_samples_leaf=2, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=11, min_samples_leaf=2, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=11, min_samples_leaf=2, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=11, min_samples_leaf=2, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=11, min_samples_leaf=2, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=11, min_samples_leaf=2, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=11, min_samples_leaf=2, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=11, min_samples_leaf=2, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=11, min_samples_leaf=4, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=11, min_samples_leaf=4, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=11, min_samples_leaf=4, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=11, min_samples_leaf=4, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=11, min_samples_leaf=4, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=11, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=11, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=11, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=11, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=11, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=11, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=11, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=11, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=11, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=11, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=13, min_samples_leaf=1, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=13, min_samples_leaf=1, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=13, min_samples_leaf=1, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=13, min_samples_leaf=1, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=13, min_samples_leaf=1, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=13, min_samples_leaf=1, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=13, min_samples_leaf=1, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=13, min_samples_leaf=1, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=13, min_samples_leaf=1, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=13, min_samples_leaf=1, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=13, min_samples_leaf=1, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=13, min_samples_leaf=1, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=13, min_samples_leaf=1, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=13, min_samples_leaf=1, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=13, min_samples_leaf=1, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=13, min_samples_leaf=2, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=13, min_samples_leaf=2, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=13, min_samples_leaf=2, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=13, min_samples_leaf=2, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=13, min_samples_leaf=2, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=13, min_samples_leaf=2, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=13, min_samples_leaf=2, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=13, min_samples_leaf=2, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=13, min_samples_leaf=2, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=13, min_samples_leaf=2, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=13, min_samples_leaf=2, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=13, min_samples_leaf=2, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=13, min_samples_leaf=2, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=13, min_samples_leaf=2, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=13, min_samples_leaf=2, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=13, min_samples_leaf=4, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=13, min_samples_leaf=4, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=13, min_samples_leaf=4, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=13, min_samples_leaf=4, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=13, min_samples_leaf=4, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=13, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=13, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=13, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=13, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=13, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=13, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=13, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=13, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=13, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=13, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=15, min_samples_leaf=1, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=15, min_samples_leaf=1, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=15, min_samples_leaf=1, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=15, min_samples_leaf=1, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=15, min_samples_leaf=1, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=15, min_samples_leaf=1, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=15, min_samples_leaf=1, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=15, min_samples_leaf=1, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=15, min_samples_leaf=1, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=15, min_samples_leaf=1, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=15, min_samples_leaf=1, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=15, min_samples_leaf=1, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=15, min_samples_leaf=1, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=15, min_samples_leaf=1, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=15, min_samples_leaf=1, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=15, min_samples_leaf=2, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=15, min_samples_leaf=2, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=15, min_samples_leaf=2, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=15, min_samples_leaf=2, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=15, min_samples_leaf=2, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=15, min_samples_leaf=2, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=15, min_samples_leaf=2, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=15, min_samples_leaf=2, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=15, min_samples_leaf=2, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=15, min_samples_leaf=2, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=15, min_samples_leaf=2, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=15, min_samples_leaf=2, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=15, min_samples_leaf=2, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=15, min_samples_leaf=2, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=15, min_samples_leaf=2, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=15, min_samples_leaf=4, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=15, min_samples_leaf=4, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=15, min_samples_leaf=4, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=15, min_samples_leaf=4, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=15, min_samples_leaf=4, min_samples_split=2; total time=   0.1s
# [CV] END criterion=gini, max_depth=15, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=15, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=15, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=15, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=15, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END criterion=gini, max_depth=15, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=15, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=15, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=15, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END criterion=gini, max_depth=15, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=1, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=1, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=1, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=1, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=1, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=1, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=1, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=1, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=1, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=1, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=1, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=1, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=1, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=1, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=1, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=2, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=2, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=2, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=2, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=2, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=2, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=2, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=2, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=2, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=2, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=2, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=2, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=2, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=2, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=2, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=4, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=4, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=4, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=4, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=4, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=1, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=1, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=1, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=1, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=1, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=1, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=1, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=1, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=1, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=1, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=1, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=1, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=1, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=1, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=1, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=2, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=2, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=2, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=2, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=2, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=2, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=2, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=2, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=2, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=2, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=2, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=2, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=2, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=2, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=2, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=4, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=4, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=4, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=4, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=4, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=9, min_samples_leaf=1, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=9, min_samples_leaf=1, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=9, min_samples_leaf=1, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=9, min_samples_leaf=1, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=9, min_samples_leaf=1, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=9, min_samples_leaf=1, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=9, min_samples_leaf=1, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=9, min_samples_leaf=1, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=9, min_samples_leaf=1, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=9, min_samples_leaf=1, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=9, min_samples_leaf=1, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=9, min_samples_leaf=1, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=9, min_samples_leaf=1, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=9, min_samples_leaf=1, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=9, min_samples_leaf=1, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=9, min_samples_leaf=2, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=9, min_samples_leaf=2, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=9, min_samples_leaf=2, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=9, min_samples_leaf=2, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=9, min_samples_leaf=2, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=9, min_samples_leaf=2, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=9, min_samples_leaf=2, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=9, min_samples_leaf=2, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=9, min_samples_leaf=2, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=9, min_samples_leaf=2, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=9, min_samples_leaf=2, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=9, min_samples_leaf=2, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=9, min_samples_leaf=2, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=9, min_samples_leaf=2, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=9, min_samples_leaf=2, min_samples_split=10; total time=   0.2s
# [CV] END criterion=entropy, max_depth=9, min_samples_leaf=4, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=9, min_samples_leaf=4, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=9, min_samples_leaf=4, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=9, min_samples_leaf=4, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=9, min_samples_leaf=4, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=9, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=9, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=9, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=9, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=9, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=9, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=9, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=9, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=9, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=9, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=11, min_samples_leaf=1, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=11, min_samples_leaf=1, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=11, min_samples_leaf=1, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=11, min_samples_leaf=1, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=11, min_samples_leaf=1, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=11, min_samples_leaf=1, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=11, min_samples_leaf=1, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=11, min_samples_leaf=1, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=11, min_samples_leaf=1, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=11, min_samples_leaf=1, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=11, min_samples_leaf=1, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=11, min_samples_leaf=1, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=11, min_samples_leaf=1, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=11, min_samples_leaf=1, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=11, min_samples_leaf=1, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=11, min_samples_leaf=2, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=11, min_samples_leaf=2, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=11, min_samples_leaf=2, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=11, min_samples_leaf=2, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=11, min_samples_leaf=2, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=11, min_samples_leaf=2, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=11, min_samples_leaf=2, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=11, min_samples_leaf=2, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=11, min_samples_leaf=2, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=11, min_samples_leaf=2, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=11, min_samples_leaf=2, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=11, min_samples_leaf=2, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=11, min_samples_leaf=2, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=11, min_samples_leaf=2, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=11, min_samples_leaf=2, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=11, min_samples_leaf=4, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=11, min_samples_leaf=4, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=11, min_samples_leaf=4, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=11, min_samples_leaf=4, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=11, min_samples_leaf=4, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=11, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=11, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=11, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=11, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=11, min_samples_leaf=4, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=11, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=11, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=11, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=11, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=11, min_samples_leaf=4, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=13, min_samples_leaf=1, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=13, min_samples_leaf=1, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=13, min_samples_leaf=1, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=13, min_samples_leaf=1, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=13, min_samples_leaf=1, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=13, min_samples_leaf=1, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=13, min_samples_leaf=1, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=13, min_samples_leaf=1, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=13, min_samples_leaf=1, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=13, min_samples_leaf=1, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=13, min_samples_leaf=1, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=13, min_samples_leaf=1, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=13, min_samples_leaf=1, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=13, min_samples_leaf=1, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=13, min_samples_leaf=1, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=13, min_samples_leaf=2, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=13, min_samples_leaf=2, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=13, min_samples_leaf=2, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=13, min_samples_leaf=2, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=13, min_samples_leaf=2, min_samples_split=2; total time=   0.1s
# [CV] END criterion=entropy, max_depth=13, min_samples_leaf=2, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=13, min_samples_leaf=2, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=13, min_samples_leaf=2, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=13, min_samples_leaf=2, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=13, min_samples_leaf=2, min_samples_split=5; total time=   0.1s
# [CV] END criterion=entropy, max_depth=13, min_samples_leaf=2, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=13, min_samples_leaf=2, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=13, min_samples_leaf=2, min_samples_split=10; total time=   0.1s
# [CV] END criterion=entropy, max_depth=13, min_samples_leaf=2, min_samples_split=10; total time=   0.1s
# ...
# [CV] END criterion=ratio, max_depth=11, min_samples_leaf=1, min_samples_split=10; total time=   0.0s
# [CV] END criterion=ratio, max_depth=11, min_samples_leaf=1, min_samples_split=10; total time=   0.0s
# [CV] END criterion=ratio, max_depth=11, min_samples_leaf=1, min_samples_split=10; total time=   0.0s
# [CV] END criterion=ratio, max_depth=11, min_samples_leaf=1, min_samples_split=10; total time=   0.0s
# [CV] END criterion=ratio, max_depth=11, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END criterion=ratio, max_depth=11, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END criterion=ratio, max_depth=11, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END criterion=ratio, max_depth=11, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END criterion=ratio, max_depth=11, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END criterion=ratio, max_depth=11, min_samples_leaf=2, min_samples_split=5; total time=   0.0s
# [CV] END criterion=ratio, max_depth=11, min_samples_leaf=2, min_samples_split=5; total time=   0.0s
# [CV] END criterion=ratio, max_depth=11, min_samples_leaf=2, min_samples_split=5; total time=   0.0s
# [CV] END criterion=ratio, max_depth=11, min_samples_leaf=2, min_samples_split=5; total time=   0.0s
# [CV] END criterion=ratio, max_depth=11, min_samples_leaf=2, min_samples_split=5; total time=   0.0s
# [CV] END criterion=ratio, max_depth=11, min_samples_leaf=2, min_samples_split=10; total time=   0.0s
# [CV] END criterion=ratio, max_depth=11, min_samples_leaf=2, min_samples_split=10; total time=   0.0s
# [CV] END criterion=ratio, max_depth=11, min_samples_leaf=2, min_samples_split=10; total time=   0.0s
# [CV] END criterion=ratio, max_depth=11, min_samples_leaf=2, min_samples_split=10; total time=   0.0s
# [CV] END criterion=ratio, max_depth=11, min_samples_leaf=2, min_samples_split=10; total time=   0.0s
# [CV] END criterion=ratio, max_depth=11, min_samples_leaf=4, min_samples_split=2; total time=   0.0s
# [CV] END criterion=ratio, max_depth=11, min_samples_leaf=4, min_samples_split=2; total time=   0.0s
# [CV] END criterion=ratio, max_depth=11, min_samples_leaf=4, min_samples_split=2; total time=   0.0s
# [CV] END criterion=ratio, max_depth=11, min_samples_leaf=4, min_samples_split=2; total time=   0.0s
# [CV] END criterion=ratio, max_depth=11, min_samples_leaf=4, min_samples_split=2; total time=   0.0s
# [CV] END criterion=ratio, max_depth=11, min_samples_leaf=4, min_samples_split=5; total time=   0.0s
# [CV] END criterion=ratio, max_depth=11, min_samples_leaf=4, min_samples_split=5; total time=   0.0s
# [CV] END criterion=ratio, max_depth=11, min_samples_leaf=4, min_samples_split=5; total time=   0.0s
# [CV] END criterion=ratio, max_depth=11, min_samples_leaf=4, min_samples_split=5; total time=   0.0s
# [CV] END criterion=ratio, max_depth=11, min_samples_leaf=4, min_samples_split=5; total time=   0.0s
# [CV] END criterion=ratio, max_depth=11, min_samples_leaf=4, min_samples_split=10; total time=   0.0s
# [CV] END criterion=ratio, max_depth=11, min_samples_leaf=4, min_samples_split=10; total time=   0.0s
# [CV] END criterion=ratio, max_depth=11, min_samples_leaf=4, min_samples_split=10; total time=   0.0s
# [CV] END criterion=ratio, max_depth=11, min_samples_leaf=4, min_samples_split=10; total time=   0.0s
# [CV] END criterion=ratio, max_depth=11, min_samples_leaf=4, min_samples_split=10; total time=   0.0s
# [CV] END criterion=ratio, max_depth=13, min_samples_leaf=1, min_samples_split=2; total time=   0.0s
# [CV] END criterion=ratio, max_depth=13, min_samples_leaf=1, min_samples_split=2; total time=   0.0s
# [CV] END criterion=ratio, max_depth=13, min_samples_leaf=1, min_samples_split=2; total time=   0.0s
# [CV] END criterion=ratio, max_depth=13, min_samples_leaf=1, min_samples_split=2; total time=   0.0s
# [CV] END criterion=ratio, max_depth=13, min_samples_leaf=1, min_samples_split=2; total time=   0.0s
# [CV] END criterion=ratio, max_depth=13, min_samples_leaf=1, min_samples_split=5; total time=   0.0s
# [CV] END criterion=ratio, max_depth=13, min_samples_leaf=1, min_samples_split=5; total time=   0.0s
# [CV] END criterion=ratio, max_depth=13, min_samples_leaf=1, min_samples_split=5; total time=   0.0s
# [CV] END criterion=ratio, max_depth=13, min_samples_leaf=1, min_samples_split=5; total time=   0.0s
# [CV] END criterion=ratio, max_depth=13, min_samples_leaf=1, min_samples_split=5; total time=   0.0s
# [CV] END criterion=ratio, max_depth=13, min_samples_leaf=1, min_samples_split=10; total time=   0.0s
# [CV] END criterion=ratio, max_depth=13, min_samples_leaf=1, min_samples_split=10; total time=   0.0s
# [CV] END criterion=ratio, max_depth=13, min_samples_leaf=1, min_samples_split=10; total time=   0.0s
# [CV] END criterion=ratio, max_depth=13, min_samples_leaf=1, min_samples_split=10; total time=   0.0s
# [CV] END criterion=ratio, max_depth=13, min_samples_leaf=1, min_samples_split=10; total time=   0.0s
# [CV] END criterion=ratio, max_depth=13, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END criterion=ratio, max_depth=13, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END criterion=ratio, max_depth=13, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END criterion=ratio, max_depth=13, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END criterion=ratio, max_depth=13, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END criterion=ratio, max_depth=13, min_samples_leaf=2, min_samples_split=5; total time=   0.0s
# [CV] END criterion=ratio, max_depth=13, min_samples_leaf=2, min_samples_split=5; total time=   0.0s
# [CV] END criterion=ratio, max_depth=13, min_samples_leaf=2, min_samples_split=5; total time=   0.0s
# [CV] END criterion=ratio, max_depth=13, min_samples_leaf=2, min_samples_split=5; total time=   0.0s
# [CV] END criterion=ratio, max_depth=13, min_samples_leaf=2, min_samples_split=5; total time=   0.0s
# [CV] END criterion=ratio, max_depth=13, min_samples_leaf=2, min_samples_split=10; total time=   0.0s
# [CV] END criterion=ratio, max_depth=13, min_samples_leaf=2, min_samples_split=10; total time=   0.0s
# [CV] END criterion=ratio, max_depth=13, min_samples_leaf=2, min_samples_split=10; total time=   0.0s
# [CV] END criterion=ratio, max_depth=13, min_samples_leaf=2, min_samples_split=10; total time=   0.0s
# [CV] END criterion=ratio, max_depth=13, min_samples_leaf=2, min_samples_split=10; total time=   0.0s
# [CV] END criterion=ratio, max_depth=13, min_samples_leaf=4, min_samples_split=2; total time=   0.0s
# [CV] END criterion=ratio, max_depth=13, min_samples_leaf=4, min_samples_split=2; total time=   0.0s
# [CV] END criterion=ratio, max_depth=13, min_samples_leaf=4, min_samples_split=2; total time=   0.0s
# [CV] END criterion=ratio, max_depth=13, min_samples_leaf=4, min_samples_split=2; total time=   0.0s
# [CV] END criterion=ratio, max_depth=13, min_samples_leaf=4, min_samples_split=2; total time=   0.0s
# [CV] END criterion=ratio, max_depth=13, min_samples_leaf=4, min_samples_split=5; total time=   0.0s
# [CV] END criterion=ratio, max_depth=13, min_samples_leaf=4, min_samples_split=5; total time=   0.0s
# [CV] END criterion=ratio, max_depth=13, min_samples_leaf=4, min_samples_split=5; total time=   0.0s
# [CV] END criterion=ratio, max_depth=13, min_samples_leaf=4, min_samples_split=5; total time=   0.0s
# [CV] END criterion=ratio, max_depth=13, min_samples_leaf=4, min_samples_split=5; total time=   0.0s
# [CV] END criterion=ratio, max_depth=13, min_samples_leaf=4, min_samples_split=10; total time=   0.0s
# [CV] END criterion=ratio, max_depth=13, min_samples_leaf=4, min_samples_split=10; total time=   0.0s
# [CV] END criterion=ratio, max_depth=13, min_samples_leaf=4, min_samples_split=10; total time=   0.0s
# [CV] END criterion=ratio, max_depth=13, min_samples_leaf=4, min_samples_split=10; total time=   0.0s
# [CV] END criterion=ratio, max_depth=13, min_samples_leaf=4, min_samples_split=10; total time=   0.0s
# [CV] END criterion=ratio, max_depth=15, min_samples_leaf=1, min_samples_split=2; total time=   0.0s
# [CV] END criterion=ratio, max_depth=15, min_samples_leaf=1, min_samples_split=2; total time=   0.0s
# [CV] END criterion=ratio, max_depth=15, min_samples_leaf=1, min_samples_split=2; total time=   0.0s
# [CV] END criterion=ratio, max_depth=15, min_samples_leaf=1, min_samples_split=2; total time=   0.0s
# [CV] END criterion=ratio, max_depth=15, min_samples_leaf=1, min_samples_split=2; total time=   0.0s
# [CV] END criterion=ratio, max_depth=15, min_samples_leaf=1, min_samples_split=5; total time=   0.0s
# [CV] END criterion=ratio, max_depth=15, min_samples_leaf=1, min_samples_split=5; total time=   0.0s
# [CV] END criterion=ratio, max_depth=15, min_samples_leaf=1, min_samples_split=5; total time=   0.0s
# [CV] END criterion=ratio, max_depth=15, min_samples_leaf=1, min_samples_split=5; total time=   0.0s
# [CV] END criterion=ratio, max_depth=15, min_samples_leaf=1, min_samples_split=5; total time=   0.0s
# [CV] END criterion=ratio, max_depth=15, min_samples_leaf=1, min_samples_split=10; total time=   0.0s
# [CV] END criterion=ratio, max_depth=15, min_samples_leaf=1, min_samples_split=10; total time=   0.0s
# [CV] END criterion=ratio, max_depth=15, min_samples_leaf=1, min_samples_split=10; total time=   0.0s
# [CV] END criterion=ratio, max_depth=15, min_samples_leaf=1, min_samples_split=10; total time=   0.0s
# [CV] END criterion=ratio, max_depth=15, min_samples_leaf=1, min_samples_split=10; total time=   0.0s
# [CV] END criterion=ratio, max_depth=15, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END criterion=ratio, max_depth=15, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END criterion=ratio, max_depth=15, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END criterion=ratio, max_depth=15, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END criterion=ratio, max_depth=15, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END criterion=ratio, max_depth=15, min_samples_leaf=2, min_samples_split=5; total time=   0.0s
# [CV] END criterion=ratio, max_depth=15, min_samples_leaf=2, min_samples_split=5; total time=   0.0s
# [CV] END criterion=ratio, max_depth=15, min_samples_leaf=2, min_samples_split=5; total time=   0.0s
# [CV] END criterion=ratio, max_depth=15, min_samples_leaf=2, min_samples_split=5; total time=   0.0s
# [CV] END criterion=ratio, max_depth=15, min_samples_leaf=2, min_samples_split=5; total time=   0.0s
# [CV] END criterion=ratio, max_depth=15, min_samples_leaf=2, min_samples_split=10; total time=   0.0s
# [CV] END criterion=ratio, max_depth=15, min_samples_leaf=2, min_samples_split=10; total time=   0.0s
# [CV] END criterion=ratio, max_depth=15, min_samples_leaf=2, min_samples_split=10; total time=   0.0s
# [CV] END criterion=ratio, max_depth=15, min_samples_leaf=2, min_samples_split=10; total time=   0.0s
# [CV] END criterion=ratio, max_depth=15, min_samples_leaf=2, min_samples_split=10; total time=   0.0s
# [CV] END criterion=ratio, max_depth=15, min_samples_leaf=4, min_samples_split=2; total time=   0.0s
# [CV] END criterion=ratio, max_depth=15, min_samples_leaf=4, min_samples_split=2; total time=   0.0s
# [CV] END criterion=ratio, max_depth=15, min_samples_leaf=4, min_samples_split=2; total time=   0.0s
# [CV] END criterion=ratio, max_depth=15, min_samples_leaf=4, min_samples_split=2; total time=   0.0s
# [CV] END criterion=ratio, max_depth=15, min_samples_leaf=4, min_samples_split=2; total time=   0.0s
# [CV] END criterion=ratio, max_depth=15, min_samples_leaf=4, min_samples_split=5; total time=   0.0s
# [CV] END criterion=ratio, max_depth=15, min_samples_leaf=4, min_samples_split=5; total time=   0.0s
# [CV] END criterion=ratio, max_depth=15, min_samples_leaf=4, min_samples_split=5; total time=   0.0s
# [CV] END criterion=ratio, max_depth=15, min_samples_leaf=4, min_samples_split=5; total time=   0.0s
# [CV] END criterion=ratio, max_depth=15, min_samples_leaf=4, min_samples_split=5; total time=   0.0s
# [CV] END criterion=ratio, max_depth=15, min_samples_leaf=4, min_samples_split=10; total time=   0.0s
# [CV] END criterion=ratio, max_depth=15, min_samples_leaf=4, min_samples_split=10; total time=   0.0s
# [CV] END criterion=ratio, max_depth=15, min_samples_leaf=4, min_samples_split=10; total time=   0.0s
# [CV] END criterion=ratio, max_depth=15, min_samples_leaf=4, min_samples_split=10; total time=   0.0s
# [CV] END criterion=ratio, max_depth=15, min_samples_leaf=4, min_samples_split=10; total time=   0.0s
# /home/goncalo/miniconda3/envs/daa310/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:425: FitFailedWarning:
# 270 fits failed out of a total of 810.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 270 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/goncalo/miniconda3/envs/daa310/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/goncalo/miniconda3/envs/daa310/lib/python3.10/site-packages/sklearn/base.py", line 1144, in wrapper
#     estimator._validate_params()
#   File "/home/goncalo/miniconda3/envs/daa310/lib/python3.10/site-packages/sklearn/base.py", line 637, in _validate_params
#     validate_parameter_constraints(
#   File "/home/goncalo/miniconda3/envs/daa310/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'criterion' parameter of DecisionTreeClassifier must be a str among {'entropy', 'gini', 'log_loss'}. Got 'ratio' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /home/goncalo/miniconda3/envs/daa310/lib/python3.10/site-packages/sklearn/model_selection/_search.py:976: UserWarning: One or more of the test scores are non-finite: [0.84577309 0.84577309 0.84577309 0.84595466 0.84595466 0.84595466
#  0.84586387 0.84586387 0.84586387 0.84350461 0.84341378 0.84459403
#  0.84323234 0.84332312 0.84486643 0.84386779 0.84386779 0.84459407
#  0.83261128 0.83179434 0.83442715 0.83206694 0.8328838  0.83451789
#  0.83351926 0.83351926 0.83361004 0.82307915 0.82326002 0.82625705
#  0.823533   0.82289758 0.82752788 0.82861673 0.82861673 0.82870727
#  0.81835791 0.81981043 0.81736034 0.81899365 0.82198924 0.82335196
#  0.8211725  0.8211725  0.82271572 0.81563427 0.81345562 0.8178139
#  0.81663336 0.81754092 0.82171746 0.81881204 0.81881204 0.82053667
#  0.84141605 0.84141605 0.84141605 0.84141605 0.84141605 0.84141605
#  0.84141605 0.84141605 0.84141605 0.84459399 0.84404928 0.84468461
#  0.8441399  0.8441399  0.8447754  0.84668176 0.84668176 0.84640949
#  0.83869377 0.83878468 0.84014638 0.83923844 0.83887514 0.84014634
#  0.84368651 0.84368651 0.84159857 0.83306529 0.83106822 0.83170363
#  0.83179458 0.83152194 0.83279293 0.83342938 0.83342938 0.83270252
#  0.8228987  0.82489572 0.82671098 0.82289804 0.8238056  0.82471407
#  0.82888921 0.82888921 0.82734639 0.82371498 0.82053852 0.82244448
#  0.81935704 0.82162696 0.82380605 0.82652932 0.82652932 0.82589358
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan]
#   warnings.warn(

# %% [markdown]
# ### Previsões do modelo

# %%
y_pred = clf.predict(df_test)

# %% [markdown]
# ### Escrita em ficheiro csv

# %%
df_predicoes = pd.DataFrame({'Result': y_pred})
df_predicoes['RowId'] = range(1, len(y_pred) + 1)
df_predicoes = df_predicoes[['RowId', 'Result']]

df_predicoes.to_csv('../../datasets/parte2/teste/previsoesDecisionTreeClassifier.csv', index=False)
