# %% [markdown]
# ## Modelo criado para a competição da 2ºFase do trabalho da UC de Dados e Aprendizagem Automática

# %% [markdown]
# ### OBJETIVO -  PREVER A quantidade de energia injectada na rede eléctrica QUE SE ENCONTRA NA COLUNA Injeção na rede (kWh) DO DATASET DE ENERGIA

# %% [markdown]
# ### Modelo utilizado - Random Forest Classifier

# %% [markdown]
# ### Imports de bicilotecas necessárias para desenvolver o modelo

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# ### Leitura do dataset que contêm os dados globais

# %%
df = pd.read_csv('../../datasets/parte2/treino/datasetGlobal.csv', na_filter= False)
df_test = pd.read_csv('../../datasets/parte2/teste/datasetGlobal.csv')

# %% [markdown]
# ### Criação da variavel que queremos prever

# %%
x = df.drop('Injeção na rede (kWh)', axis = 1)
y = df['Injeção na rede (kWh)']

# %% [markdown]
# ### Criação do modelo de random forest, com 100 árvores

# %%
param_grid = {
    'criterion': ['gini', 'entropy','ratio'],
    'max_depth': [5,7,9,11,13,15],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
}
model = RandomForestClassifier(n_estimators=100, random_state=2023)

# Use GridSearchCV para encontrar os melhores hiperparâmetros
grid_search = GridSearchCV(estimator=model, param_grid=param_grid,refit=True, verbose=2)
grid_search.fit(x, y)
model = grid_search.best_estimator_
# Out:
# Fitting 5 folds for each of 162 candidates, totalling 810 fits
# [CV] END criterion=gini, max_depth=5, min_samples_leaf=1, min_samples_split=2; total time=   1.2s
# [CV] END criterion=gini, max_depth=5, min_samples_leaf=1, min_samples_split=2; total time=   1.3s
# [CV] END criterion=gini, max_depth=5, min_samples_leaf=1, min_samples_split=2; total time=   1.2s
# [CV] END criterion=gini, max_depth=5, min_samples_leaf=1, min_samples_split=2; total time=   1.1s
# [CV] END criterion=gini, max_depth=5, min_samples_leaf=1, min_samples_split=2; total time=   1.1s
# [CV] END criterion=gini, max_depth=5, min_samples_leaf=1, min_samples_split=5; total time=   1.1s
# [CV] END criterion=gini, max_depth=5, min_samples_leaf=1, min_samples_split=5; total time=   1.1s
# [CV] END criterion=gini, max_depth=5, min_samples_leaf=1, min_samples_split=5; total time=   1.2s
# [CV] END criterion=gini, max_depth=5, min_samples_leaf=1, min_samples_split=5; total time=   1.1s
# [CV] END criterion=gini, max_depth=5, min_samples_leaf=1, min_samples_split=5; total time=   1.1s
# [CV] END criterion=gini, max_depth=5, min_samples_leaf=1, min_samples_split=10; total time=   1.1s
# [CV] END criterion=gini, max_depth=5, min_samples_leaf=1, min_samples_split=10; total time=   1.1s
# [CV] END criterion=gini, max_depth=5, min_samples_leaf=1, min_samples_split=10; total time=   1.1s
# [CV] END criterion=gini, max_depth=5, min_samples_leaf=1, min_samples_split=10; total time=   1.1s
# [CV] END criterion=gini, max_depth=5, min_samples_leaf=1, min_samples_split=10; total time=   1.5s
# [CV] END criterion=gini, max_depth=5, min_samples_leaf=2, min_samples_split=2; total time=   1.3s
# [CV] END criterion=gini, max_depth=5, min_samples_leaf=2, min_samples_split=2; total time=   1.6s
# [CV] END criterion=gini, max_depth=5, min_samples_leaf=2, min_samples_split=2; total time=   1.5s
# [CV] END criterion=gini, max_depth=5, min_samples_leaf=2, min_samples_split=2; total time=   1.4s
# [CV] END criterion=gini, max_depth=5, min_samples_leaf=2, min_samples_split=2; total time=   1.4s
# [CV] END criterion=gini, max_depth=5, min_samples_leaf=2, min_samples_split=5; total time=   1.8s
# [CV] END criterion=gini, max_depth=5, min_samples_leaf=2, min_samples_split=5; total time=   1.5s
# [CV] END criterion=gini, max_depth=5, min_samples_leaf=2, min_samples_split=5; total time=   1.5s
# [CV] END criterion=gini, max_depth=5, min_samples_leaf=2, min_samples_split=5; total time=   1.4s
# [CV] END criterion=gini, max_depth=5, min_samples_leaf=2, min_samples_split=5; total time=   1.4s
# [CV] END criterion=gini, max_depth=5, min_samples_leaf=2, min_samples_split=10; total time=   1.4s
# [CV] END criterion=gini, max_depth=5, min_samples_leaf=2, min_samples_split=10; total time=   1.5s
# [CV] END criterion=gini, max_depth=5, min_samples_leaf=2, min_samples_split=10; total time=   1.4s
# [CV] END criterion=gini, max_depth=5, min_samples_leaf=2, min_samples_split=10; total time=   1.3s
# [CV] END criterion=gini, max_depth=5, min_samples_leaf=2, min_samples_split=10; total time=   1.4s
# [CV] END criterion=gini, max_depth=5, min_samples_leaf=4, min_samples_split=2; total time=   1.4s
# [CV] END criterion=gini, max_depth=5, min_samples_leaf=4, min_samples_split=2; total time=   1.4s
# [CV] END criterion=gini, max_depth=5, min_samples_leaf=4, min_samples_split=2; total time=   1.3s
# [CV] END criterion=gini, max_depth=5, min_samples_leaf=4, min_samples_split=2; total time=   1.3s
# [CV] END criterion=gini, max_depth=5, min_samples_leaf=4, min_samples_split=2; total time=   1.3s
# [CV] END criterion=gini, max_depth=5, min_samples_leaf=4, min_samples_split=5; total time=   1.3s
# [CV] END criterion=gini, max_depth=5, min_samples_leaf=4, min_samples_split=5; total time=   1.5s
# [CV] END criterion=gini, max_depth=5, min_samples_leaf=4, min_samples_split=5; total time=   1.3s
# [CV] END criterion=gini, max_depth=5, min_samples_leaf=4, min_samples_split=5; total time=   1.2s
# [CV] END criterion=gini, max_depth=5, min_samples_leaf=4, min_samples_split=5; total time=   1.3s
# [CV] END criterion=gini, max_depth=5, min_samples_leaf=4, min_samples_split=10; total time=   1.4s
# [CV] END criterion=gini, max_depth=5, min_samples_leaf=4, min_samples_split=10; total time=   1.2s
# [CV] END criterion=gini, max_depth=5, min_samples_leaf=4, min_samples_split=10; total time=   1.3s
# [CV] END criterion=gini, max_depth=5, min_samples_leaf=4, min_samples_split=10; total time=   1.3s
# [CV] END criterion=gini, max_depth=5, min_samples_leaf=4, min_samples_split=10; total time=   1.3s
# [CV] END criterion=gini, max_depth=7, min_samples_leaf=1, min_samples_split=2; total time=   1.5s
# [CV] END criterion=gini, max_depth=7, min_samples_leaf=1, min_samples_split=2; total time=   1.7s
# [CV] END criterion=gini, max_depth=7, min_samples_leaf=1, min_samples_split=2; total time=   1.5s
# [CV] END criterion=gini, max_depth=7, min_samples_leaf=1, min_samples_split=2; total time=   1.5s
# [CV] END criterion=gini, max_depth=7, min_samples_leaf=1, min_samples_split=2; total time=   1.5s
# [CV] END criterion=gini, max_depth=7, min_samples_leaf=1, min_samples_split=5; total time=   1.6s
# [CV] END criterion=gini, max_depth=7, min_samples_leaf=1, min_samples_split=5; total time=   1.9s
# [CV] END criterion=gini, max_depth=7, min_samples_leaf=1, min_samples_split=5; total time=   1.8s
# [CV] END criterion=gini, max_depth=7, min_samples_leaf=1, min_samples_split=5; total time=   1.8s
# [CV] END criterion=gini, max_depth=7, min_samples_leaf=1, min_samples_split=5; total time=   1.7s
# [CV] END criterion=gini, max_depth=7, min_samples_leaf=1, min_samples_split=10; total time=   1.5s
# [CV] END criterion=gini, max_depth=7, min_samples_leaf=1, min_samples_split=10; total time=   1.5s
# [CV] END criterion=gini, max_depth=7, min_samples_leaf=1, min_samples_split=10; total time=   1.7s
# [CV] END criterion=gini, max_depth=7, min_samples_leaf=1, min_samples_split=10; total time=   1.8s
# [CV] END criterion=gini, max_depth=7, min_samples_leaf=1, min_samples_split=10; total time=   1.6s
# [CV] END criterion=gini, max_depth=7, min_samples_leaf=2, min_samples_split=2; total time=   1.7s
# [CV] END criterion=gini, max_depth=7, min_samples_leaf=2, min_samples_split=2; total time=   1.5s
# [CV] END criterion=gini, max_depth=7, min_samples_leaf=2, min_samples_split=2; total time=   1.7s
# [CV] END criterion=gini, max_depth=7, min_samples_leaf=2, min_samples_split=2; total time=   1.2s
# [CV] END criterion=gini, max_depth=7, min_samples_leaf=2, min_samples_split=2; total time=   1.1s
# [CV] END criterion=gini, max_depth=7, min_samples_leaf=2, min_samples_split=5; total time=   1.2s
# [CV] END criterion=gini, max_depth=7, min_samples_leaf=2, min_samples_split=5; total time=   1.2s
# [CV] END criterion=gini, max_depth=7, min_samples_leaf=2, min_samples_split=5; total time=   1.8s
# [CV] END criterion=gini, max_depth=7, min_samples_leaf=2, min_samples_split=5; total time=   1.5s
# [CV] END criterion=gini, max_depth=7, min_samples_leaf=2, min_samples_split=5; total time=   1.5s
# [CV] END criterion=gini, max_depth=7, min_samples_leaf=2, min_samples_split=10; total time=   1.5s
# [CV] END criterion=gini, max_depth=7, min_samples_leaf=2, min_samples_split=10; total time=   1.5s
# [CV] END criterion=gini, max_depth=7, min_samples_leaf=2, min_samples_split=10; total time=   1.5s
# [CV] END criterion=gini, max_depth=7, min_samples_leaf=2, min_samples_split=10; total time=   1.3s
# [CV] END criterion=gini, max_depth=7, min_samples_leaf=2, min_samples_split=10; total time=   1.1s
# [CV] END criterion=gini, max_depth=7, min_samples_leaf=4, min_samples_split=2; total time=   1.1s
# [CV] END criterion=gini, max_depth=7, min_samples_leaf=4, min_samples_split=2; total time=   1.6s
# [CV] END criterion=gini, max_depth=7, min_samples_leaf=4, min_samples_split=2; total time=   1.5s
# [CV] END criterion=gini, max_depth=7, min_samples_leaf=4, min_samples_split=2; total time=   1.5s
# [CV] END criterion=gini, max_depth=7, min_samples_leaf=4, min_samples_split=2; total time=   1.5s
# [CV] END criterion=gini, max_depth=7, min_samples_leaf=4, min_samples_split=5; total time=   1.5s
# [CV] END criterion=gini, max_depth=7, min_samples_leaf=4, min_samples_split=5; total time=   1.4s
# [CV] END criterion=gini, max_depth=7, min_samples_leaf=4, min_samples_split=5; total time=   1.5s
# [CV] END criterion=gini, max_depth=7, min_samples_leaf=4, min_samples_split=5; total time=   1.5s
# [CV] END criterion=gini, max_depth=7, min_samples_leaf=4, min_samples_split=5; total time=   1.5s
# [CV] END criterion=gini, max_depth=7, min_samples_leaf=4, min_samples_split=10; total time=   1.5s
# [CV] END criterion=gini, max_depth=7, min_samples_leaf=4, min_samples_split=10; total time=   1.5s
# [CV] END criterion=gini, max_depth=7, min_samples_leaf=4, min_samples_split=10; total time=   1.5s
# [CV] END criterion=gini, max_depth=7, min_samples_leaf=4, min_samples_split=10; total time=   1.4s
# [CV] END criterion=gini, max_depth=7, min_samples_leaf=4, min_samples_split=10; total time=   1.5s
# [CV] END criterion=gini, max_depth=9, min_samples_leaf=1, min_samples_split=2; total time=   1.7s
# [CV] END criterion=gini, max_depth=9, min_samples_leaf=1, min_samples_split=2; total time=   1.7s
# [CV] END criterion=gini, max_depth=9, min_samples_leaf=1, min_samples_split=2; total time=   1.7s
# [CV] END criterion=gini, max_depth=9, min_samples_leaf=1, min_samples_split=2; total time=   1.6s
# [CV] END criterion=gini, max_depth=9, min_samples_leaf=1, min_samples_split=2; total time=   1.5s
# [CV] END criterion=gini, max_depth=9, min_samples_leaf=1, min_samples_split=5; total time=   1.3s
# [CV] END criterion=gini, max_depth=9, min_samples_leaf=1, min_samples_split=5; total time=   1.2s
# [CV] END criterion=gini, max_depth=9, min_samples_leaf=1, min_samples_split=5; total time=   1.5s
# [CV] END criterion=gini, max_depth=9, min_samples_leaf=1, min_samples_split=5; total time=   1.5s
# [CV] END criterion=gini, max_depth=9, min_samples_leaf=1, min_samples_split=5; total time=   1.9s
# [CV] END criterion=gini, max_depth=9, min_samples_leaf=1, min_samples_split=10; total time=   1.8s
# [CV] END criterion=gini, max_depth=9, min_samples_leaf=1, min_samples_split=10; total time=   1.7s
# [CV] END criterion=gini, max_depth=9, min_samples_leaf=1, min_samples_split=10; total time=   1.7s
# [CV] END criterion=gini, max_depth=9, min_samples_leaf=1, min_samples_split=10; total time=   1.6s
# [CV] END criterion=gini, max_depth=9, min_samples_leaf=1, min_samples_split=10; total time=   1.6s
# [CV] END criterion=gini, max_depth=9, min_samples_leaf=2, min_samples_split=2; total time=   1.6s
# [CV] END criterion=gini, max_depth=9, min_samples_leaf=2, min_samples_split=2; total time=   1.7s
# [CV] END criterion=gini, max_depth=9, min_samples_leaf=2, min_samples_split=2; total time=   1.8s
# [CV] END criterion=gini, max_depth=9, min_samples_leaf=2, min_samples_split=2; total time=   1.4s
# [CV] END criterion=gini, max_depth=9, min_samples_leaf=2, min_samples_split=2; total time=   1.6s
# [CV] END criterion=gini, max_depth=9, min_samples_leaf=2, min_samples_split=5; total time=   1.2s
# [CV] END criterion=gini, max_depth=9, min_samples_leaf=2, min_samples_split=5; total time=   1.2s
# [CV] END criterion=gini, max_depth=9, min_samples_leaf=2, min_samples_split=5; total time=   1.6s
# [CV] END criterion=gini, max_depth=9, min_samples_leaf=2, min_samples_split=5; total time=   1.1s
# [CV] END criterion=gini, max_depth=9, min_samples_leaf=2, min_samples_split=5; total time=   1.2s
# [CV] END criterion=gini, max_depth=9, min_samples_leaf=2, min_samples_split=10; total time=   1.2s
# [CV] END criterion=gini, max_depth=9, min_samples_leaf=2, min_samples_split=10; total time=   1.5s
# [CV] END criterion=gini, max_depth=9, min_samples_leaf=2, min_samples_split=10; total time=   1.5s
# [CV] END criterion=gini, max_depth=9, min_samples_leaf=2, min_samples_split=10; total time=   1.5s
# [CV] END criterion=gini, max_depth=9, min_samples_leaf=2, min_samples_split=10; total time=   1.5s
# [CV] END criterion=gini, max_depth=9, min_samples_leaf=4, min_samples_split=2; total time=   1.5s
# [CV] END criterion=gini, max_depth=9, min_samples_leaf=4, min_samples_split=2; total time=   1.6s
# [CV] END criterion=gini, max_depth=9, min_samples_leaf=4, min_samples_split=2; total time=   2.0s
# [CV] END criterion=gini, max_depth=9, min_samples_leaf=4, min_samples_split=2; total time=   1.7s
# [CV] END criterion=gini, max_depth=9, min_samples_leaf=4, min_samples_split=2; total time=   1.7s
# [CV] END criterion=gini, max_depth=9, min_samples_leaf=4, min_samples_split=5; total time=   1.7s
# [CV] END criterion=gini, max_depth=9, min_samples_leaf=4, min_samples_split=5; total time=   1.9s
# [CV] END criterion=gini, max_depth=9, min_samples_leaf=4, min_samples_split=5; total time=   1.8s
# [CV] END criterion=gini, max_depth=9, min_samples_leaf=4, min_samples_split=5; total time=   1.9s
# [CV] END criterion=gini, max_depth=9, min_samples_leaf=4, min_samples_split=5; total time=   1.8s
# [CV] END criterion=gini, max_depth=9, min_samples_leaf=4, min_samples_split=10; total time=   1.7s
# [CV] END criterion=gini, max_depth=9, min_samples_leaf=4, min_samples_split=10; total time=   1.7s
# [CV] END criterion=gini, max_depth=9, min_samples_leaf=4, min_samples_split=10; total time=   1.6s
# [CV] END criterion=gini, max_depth=9, min_samples_leaf=4, min_samples_split=10; total time=   1.6s
# [CV] END criterion=gini, max_depth=9, min_samples_leaf=4, min_samples_split=10; total time=   1.4s
# [CV] END criterion=gini, max_depth=11, min_samples_leaf=1, min_samples_split=2; total time=   1.3s
# [CV] END criterion=gini, max_depth=11, min_samples_leaf=1, min_samples_split=2; total time=   2.0s
# [CV] END criterion=gini, max_depth=11, min_samples_leaf=1, min_samples_split=2; total time=   1.8s
# [CV] END criterion=gini, max_depth=11, min_samples_leaf=1, min_samples_split=2; total time=   1.7s
# [CV] END criterion=gini, max_depth=11, min_samples_leaf=1, min_samples_split=2; total time=   1.8s
# [CV] END criterion=gini, max_depth=11, min_samples_leaf=1, min_samples_split=5; total time=   1.8s
# [CV] END criterion=gini, max_depth=11, min_samples_leaf=1, min_samples_split=5; total time=   1.8s
# [CV] END criterion=gini, max_depth=11, min_samples_leaf=1, min_samples_split=5; total time=   2.0s
# [CV] END criterion=gini, max_depth=11, min_samples_leaf=1, min_samples_split=5; total time=   1.9s
# [CV] END criterion=gini, max_depth=11, min_samples_leaf=1, min_samples_split=5; total time=   1.9s
# [CV] END criterion=gini, max_depth=11, min_samples_leaf=1, min_samples_split=10; total time=   2.0s
# [CV] END criterion=gini, max_depth=11, min_samples_leaf=1, min_samples_split=10; total time=   1.8s
# [CV] END criterion=gini, max_depth=11, min_samples_leaf=1, min_samples_split=10; total time=   1.8s
# [CV] END criterion=gini, max_depth=11, min_samples_leaf=1, min_samples_split=10; total time=   1.7s
# [CV] END criterion=gini, max_depth=11, min_samples_leaf=1, min_samples_split=10; total time=   1.7s
# [CV] END criterion=gini, max_depth=11, min_samples_leaf=2, min_samples_split=2; total time=   1.7s
# [CV] END criterion=gini, max_depth=11, min_samples_leaf=2, min_samples_split=2; total time=   1.6s
# [CV] END criterion=gini, max_depth=11, min_samples_leaf=2, min_samples_split=2; total time=   1.8s
# [CV] END criterion=gini, max_depth=11, min_samples_leaf=2, min_samples_split=2; total time=   1.7s
# [CV] END criterion=gini, max_depth=11, min_samples_leaf=2, min_samples_split=2; total time=   1.7s
# [CV] END criterion=gini, max_depth=11, min_samples_leaf=2, min_samples_split=5; total time=   1.8s
# [CV] END criterion=gini, max_depth=11, min_samples_leaf=2, min_samples_split=5; total time=   1.8s
# [CV] END criterion=gini, max_depth=11, min_samples_leaf=2, min_samples_split=5; total time=   1.3s
# [CV] END criterion=gini, max_depth=11, min_samples_leaf=2, min_samples_split=5; total time=   1.3s
# [CV] END criterion=gini, max_depth=11, min_samples_leaf=2, min_samples_split=5; total time=   1.3s
# [CV] END criterion=gini, max_depth=11, min_samples_leaf=2, min_samples_split=10; total time=   1.3s
# [CV] END criterion=gini, max_depth=11, min_samples_leaf=2, min_samples_split=10; total time=   1.3s
# [CV] END criterion=gini, max_depth=11, min_samples_leaf=2, min_samples_split=10; total time=   1.4s
# [CV] END criterion=gini, max_depth=11, min_samples_leaf=2, min_samples_split=10; total time=   1.5s
# [CV] END criterion=gini, max_depth=11, min_samples_leaf=2, min_samples_split=10; total time=   1.3s
# [CV] END criterion=gini, max_depth=11, min_samples_leaf=4, min_samples_split=2; total time=   1.6s
# [CV] END criterion=gini, max_depth=11, min_samples_leaf=4, min_samples_split=2; total time=   1.4s
# [CV] END criterion=gini, max_depth=11, min_samples_leaf=4, min_samples_split=2; total time=   1.6s
# [CV] END criterion=gini, max_depth=11, min_samples_leaf=4, min_samples_split=2; total time=   1.9s
# [CV] END criterion=gini, max_depth=11, min_samples_leaf=4, min_samples_split=2; total time=   1.8s
# [CV] END criterion=gini, max_depth=11, min_samples_leaf=4, min_samples_split=5; total time=   1.9s
# [CV] END criterion=gini, max_depth=11, min_samples_leaf=4, min_samples_split=5; total time=   1.7s
# [CV] END criterion=gini, max_depth=11, min_samples_leaf=4, min_samples_split=5; total time=   2.0s
# [CV] END criterion=gini, max_depth=11, min_samples_leaf=4, min_samples_split=5; total time=   1.8s
# [CV] END criterion=gini, max_depth=11, min_samples_leaf=4, min_samples_split=5; total time=   1.9s
# [CV] END criterion=gini, max_depth=11, min_samples_leaf=4, min_samples_split=10; total time=   1.7s
# [CV] END criterion=gini, max_depth=11, min_samples_leaf=4, min_samples_split=10; total time=   1.8s
# [CV] END criterion=gini, max_depth=11, min_samples_leaf=4, min_samples_split=10; total time=   1.7s
# [CV] END criterion=gini, max_depth=11, min_samples_leaf=4, min_samples_split=10; total time=   1.7s
# [CV] END criterion=gini, max_depth=11, min_samples_leaf=4, min_samples_split=10; total time=   1.8s
# [CV] END criterion=gini, max_depth=13, min_samples_leaf=1, min_samples_split=2; total time=   1.8s
# [CV] END criterion=gini, max_depth=13, min_samples_leaf=1, min_samples_split=2; total time=   1.7s
# [CV] END criterion=gini, max_depth=13, min_samples_leaf=1, min_samples_split=2; total time=   1.8s
# [CV] END criterion=gini, max_depth=13, min_samples_leaf=1, min_samples_split=2; total time=   1.7s
# [CV] END criterion=gini, max_depth=13, min_samples_leaf=1, min_samples_split=2; total time=   1.3s
# [CV] END criterion=gini, max_depth=13, min_samples_leaf=1, min_samples_split=5; total time=   1.1s
# [CV] END criterion=gini, max_depth=13, min_samples_leaf=1, min_samples_split=5; total time=   1.2s
# [CV] END criterion=gini, max_depth=13, min_samples_leaf=1, min_samples_split=5; total time=   1.1s
# [CV] END criterion=gini, max_depth=13, min_samples_leaf=1, min_samples_split=5; total time=   1.1s
# [CV] END criterion=gini, max_depth=13, min_samples_leaf=1, min_samples_split=5; total time=   1.2s
# [CV] END criterion=gini, max_depth=13, min_samples_leaf=1, min_samples_split=10; total time=   1.2s
# [CV] END criterion=gini, max_depth=13, min_samples_leaf=1, min_samples_split=10; total time=   1.2s
# [CV] END criterion=gini, max_depth=13, min_samples_leaf=1, min_samples_split=10; total time=   1.1s
# [CV] END criterion=gini, max_depth=13, min_samples_leaf=1, min_samples_split=10; total time=   1.1s
# [CV] END criterion=gini, max_depth=13, min_samples_leaf=1, min_samples_split=10; total time=   1.2s
# [CV] END criterion=gini, max_depth=13, min_samples_leaf=2, min_samples_split=2; total time=   1.4s
# [CV] END criterion=gini, max_depth=13, min_samples_leaf=2, min_samples_split=2; total time=   2.1s
# [CV] END criterion=gini, max_depth=13, min_samples_leaf=2, min_samples_split=2; total time=   2.0s
# [CV] END criterion=gini, max_depth=13, min_samples_leaf=2, min_samples_split=2; total time=   1.9s
# [CV] END criterion=gini, max_depth=13, min_samples_leaf=2, min_samples_split=2; total time=   1.9s
# [CV] END criterion=gini, max_depth=13, min_samples_leaf=2, min_samples_split=5; total time=   1.6s
# [CV] END criterion=gini, max_depth=13, min_samples_leaf=2, min_samples_split=5; total time=   1.4s
# [CV] END criterion=gini, max_depth=13, min_samples_leaf=2, min_samples_split=5; total time=   1.4s
# [CV] END criterion=gini, max_depth=13, min_samples_leaf=2, min_samples_split=5; total time=   1.9s
# [CV] END criterion=gini, max_depth=13, min_samples_leaf=2, min_samples_split=5; total time=   1.8s
# [CV] END criterion=gini, max_depth=13, min_samples_leaf=2, min_samples_split=10; total time=   1.8s
# [CV] END criterion=gini, max_depth=13, min_samples_leaf=2, min_samples_split=10; total time=   1.8s
# [CV] END criterion=gini, max_depth=13, min_samples_leaf=2, min_samples_split=10; total time=   1.8s
# [CV] END criterion=gini, max_depth=13, min_samples_leaf=2, min_samples_split=10; total time=   1.8s
# [CV] END criterion=gini, max_depth=13, min_samples_leaf=2, min_samples_split=10; total time=   1.8s
# [CV] END criterion=gini, max_depth=13, min_samples_leaf=4, min_samples_split=2; total time=   1.7s
# [CV] END criterion=gini, max_depth=13, min_samples_leaf=4, min_samples_split=2; total time=   1.8s
# [CV] END criterion=gini, max_depth=13, min_samples_leaf=4, min_samples_split=2; total time=   1.8s
# [CV] END criterion=gini, max_depth=13, min_samples_leaf=4, min_samples_split=2; total time=   1.9s
# [CV] END criterion=gini, max_depth=13, min_samples_leaf=4, min_samples_split=2; total time=   1.9s
# [CV] END criterion=gini, max_depth=13, min_samples_leaf=4, min_samples_split=5; total time=   1.8s
# [CV] END criterion=gini, max_depth=13, min_samples_leaf=4, min_samples_split=5; total time=   1.8s
# [CV] END criterion=gini, max_depth=13, min_samples_leaf=4, min_samples_split=5; total time=   1.8s
# [CV] END criterion=gini, max_depth=13, min_samples_leaf=4, min_samples_split=5; total time=   1.7s
# [CV] END criterion=gini, max_depth=13, min_samples_leaf=4, min_samples_split=5; total time=   1.7s
# [CV] END criterion=gini, max_depth=13, min_samples_leaf=4, min_samples_split=10; total time=   1.7s
# [CV] END criterion=gini, max_depth=13, min_samples_leaf=4, min_samples_split=10; total time=   1.7s
# [CV] END criterion=gini, max_depth=13, min_samples_leaf=4, min_samples_split=10; total time=   1.3s
# [CV] END criterion=gini, max_depth=13, min_samples_leaf=4, min_samples_split=10; total time=   1.3s
# [CV] END criterion=gini, max_depth=13, min_samples_leaf=4, min_samples_split=10; total time=   1.3s
# [CV] END criterion=gini, max_depth=15, min_samples_leaf=1, min_samples_split=2; total time=   1.5s
# [CV] END criterion=gini, max_depth=15, min_samples_leaf=1, min_samples_split=2; total time=   1.4s
# [CV] END criterion=gini, max_depth=15, min_samples_leaf=1, min_samples_split=2; total time=   1.5s
# [CV] END criterion=gini, max_depth=15, min_samples_leaf=1, min_samples_split=2; total time=   1.6s
# [CV] END criterion=gini, max_depth=15, min_samples_leaf=1, min_samples_split=2; total time=   2.2s
# [CV] END criterion=gini, max_depth=15, min_samples_leaf=1, min_samples_split=5; total time=   1.9s
# [CV] END criterion=gini, max_depth=15, min_samples_leaf=1, min_samples_split=5; total time=   1.8s
# [CV] END criterion=gini, max_depth=15, min_samples_leaf=1, min_samples_split=5; total time=   1.5s
# [CV] END criterion=gini, max_depth=15, min_samples_leaf=1, min_samples_split=5; total time=   1.2s
# [CV] END criterion=gini, max_depth=15, min_samples_leaf=1, min_samples_split=5; total time=   2.0s
# [CV] END criterion=gini, max_depth=15, min_samples_leaf=1, min_samples_split=10; total time=   1.9s
# [CV] END criterion=gini, max_depth=15, min_samples_leaf=1, min_samples_split=10; total time=   1.7s
# [CV] END criterion=gini, max_depth=15, min_samples_leaf=1, min_samples_split=10; total time=   1.7s
# [CV] END criterion=gini, max_depth=15, min_samples_leaf=1, min_samples_split=10; total time=   1.6s
# [CV] END criterion=gini, max_depth=15, min_samples_leaf=1, min_samples_split=10; total time=   1.7s
# [CV] END criterion=gini, max_depth=15, min_samples_leaf=2, min_samples_split=2; total time=   1.8s
# [CV] END criterion=gini, max_depth=15, min_samples_leaf=2, min_samples_split=2; total time=   1.8s
# [CV] END criterion=gini, max_depth=15, min_samples_leaf=2, min_samples_split=2; total time=   2.2s
# [CV] END criterion=gini, max_depth=15, min_samples_leaf=2, min_samples_split=2; total time=   2.0s
# [CV] END criterion=gini, max_depth=15, min_samples_leaf=2, min_samples_split=2; total time=   1.8s
# [CV] END criterion=gini, max_depth=15, min_samples_leaf=2, min_samples_split=5; total time=   1.8s
# [CV] END criterion=gini, max_depth=15, min_samples_leaf=2, min_samples_split=5; total time=   1.7s
# [CV] END criterion=gini, max_depth=15, min_samples_leaf=2, min_samples_split=5; total time=   1.5s
# [CV] END criterion=gini, max_depth=15, min_samples_leaf=2, min_samples_split=5; total time=   1.7s
# [CV] END criterion=gini, max_depth=15, min_samples_leaf=2, min_samples_split=5; total time=   2.5s
# [CV] END criterion=gini, max_depth=15, min_samples_leaf=2, min_samples_split=10; total time=   1.8s
# [CV] END criterion=gini, max_depth=15, min_samples_leaf=2, min_samples_split=10; total time=   2.0s
# [CV] END criterion=gini, max_depth=15, min_samples_leaf=2, min_samples_split=10; total time=   2.0s
# [CV] END criterion=gini, max_depth=15, min_samples_leaf=2, min_samples_split=10; total time=   1.9s
# [CV] END criterion=gini, max_depth=15, min_samples_leaf=2, min_samples_split=10; total time=   1.9s
# [CV] END criterion=gini, max_depth=15, min_samples_leaf=4, min_samples_split=2; total time=   1.4s
# [CV] END criterion=gini, max_depth=15, min_samples_leaf=4, min_samples_split=2; total time=   1.4s
# [CV] END criterion=gini, max_depth=15, min_samples_leaf=4, min_samples_split=2; total time=   1.6s
# [CV] END criterion=gini, max_depth=15, min_samples_leaf=4, min_samples_split=2; total time=   1.6s
# [CV] END criterion=gini, max_depth=15, min_samples_leaf=4, min_samples_split=2; total time=   1.3s
# [CV] END criterion=gini, max_depth=15, min_samples_leaf=4, min_samples_split=5; total time=   1.5s
# [CV] END criterion=gini, max_depth=15, min_samples_leaf=4, min_samples_split=5; total time=   2.0s
# [CV] END criterion=gini, max_depth=15, min_samples_leaf=4, min_samples_split=5; total time=   1.8s
# [CV] END criterion=gini, max_depth=15, min_samples_leaf=4, min_samples_split=5; total time=   1.9s
# [CV] END criterion=gini, max_depth=15, min_samples_leaf=4, min_samples_split=5; total time=   2.0s
# [CV] END criterion=gini, max_depth=15, min_samples_leaf=4, min_samples_split=10; total time=   1.9s
# [CV] END criterion=gini, max_depth=15, min_samples_leaf=4, min_samples_split=10; total time=   1.8s
# [CV] END criterion=gini, max_depth=15, min_samples_leaf=4, min_samples_split=10; total time=   2.0s
# [CV] END criterion=gini, max_depth=15, min_samples_leaf=4, min_samples_split=10; total time=   1.8s
# [CV] END criterion=gini, max_depth=15, min_samples_leaf=4, min_samples_split=10; total time=   1.8s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=1, min_samples_split=2; total time=   1.4s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=1, min_samples_split=2; total time=   1.5s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=1, min_samples_split=2; total time=   1.5s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=1, min_samples_split=2; total time=   1.5s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=1, min_samples_split=2; total time=   1.5s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=1, min_samples_split=5; total time=   1.5s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=1, min_samples_split=5; total time=   1.6s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=1, min_samples_split=5; total time=   1.5s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=1, min_samples_split=5; total time=   1.4s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=1, min_samples_split=5; total time=   1.4s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=1, min_samples_split=10; total time=   1.4s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=1, min_samples_split=10; total time=   1.5s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=1, min_samples_split=10; total time=   1.4s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=1, min_samples_split=10; total time=   1.7s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=1, min_samples_split=10; total time=   1.7s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=2, min_samples_split=2; total time=   1.8s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=2, min_samples_split=2; total time=   1.5s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=2, min_samples_split=2; total time=   1.5s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=2, min_samples_split=2; total time=   1.5s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=2, min_samples_split=2; total time=   1.5s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=2, min_samples_split=5; total time=   1.5s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=2, min_samples_split=5; total time=   1.4s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=2, min_samples_split=5; total time=   1.6s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=2, min_samples_split=5; total time=   1.4s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=2, min_samples_split=5; total time=   1.5s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=2, min_samples_split=10; total time=   1.5s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=2, min_samples_split=10; total time=   1.6s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=2, min_samples_split=10; total time=   1.9s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=2, min_samples_split=10; total time=   1.5s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=2, min_samples_split=10; total time=   1.4s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=4, min_samples_split=2; total time=   1.4s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=4, min_samples_split=2; total time=   1.3s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=4, min_samples_split=2; total time=   1.4s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=4, min_samples_split=2; total time=   1.3s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=4, min_samples_split=2; total time=   1.4s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=4, min_samples_split=5; total time=   1.3s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=4, min_samples_split=5; total time=   1.5s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=4, min_samples_split=5; total time=   1.2s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=4, min_samples_split=5; total time=   1.2s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=4, min_samples_split=5; total time=   1.3s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=4, min_samples_split=10; total time=   1.3s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=4, min_samples_split=10; total time=   1.3s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=4, min_samples_split=10; total time=   1.2s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=4, min_samples_split=10; total time=   1.0s
# [CV] END criterion=entropy, max_depth=5, min_samples_leaf=4, min_samples_split=10; total time=   0.8s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=1, min_samples_split=2; total time=   1.0s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=1, min_samples_split=2; total time=   1.0s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=1, min_samples_split=2; total time=   1.5s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=1, min_samples_split=2; total time=   1.5s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=1, min_samples_split=2; total time=   1.6s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=1, min_samples_split=5; total time=   1.5s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=1, min_samples_split=5; total time=   1.5s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=1, min_samples_split=5; total time=   1.5s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=1, min_samples_split=5; total time=   1.4s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=1, min_samples_split=5; total time=   1.5s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=1, min_samples_split=10; total time=   1.5s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=1, min_samples_split=10; total time=   1.5s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=1, min_samples_split=10; total time=   1.5s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=1, min_samples_split=10; total time=   1.4s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=1, min_samples_split=10; total time=   1.5s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=2, min_samples_split=2; total time=   1.5s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=2, min_samples_split=2; total time=   1.4s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=2, min_samples_split=2; total time=   1.4s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=2, min_samples_split=2; total time=   1.4s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=2, min_samples_split=2; total time=   1.4s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=2, min_samples_split=5; total time=   1.3s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=2, min_samples_split=5; total time=   1.0s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=2, min_samples_split=5; total time=   1.1s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=2, min_samples_split=5; total time=   0.9s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=2, min_samples_split=5; total time=   1.0s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=2, min_samples_split=10; total time=   0.9s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=2, min_samples_split=10; total time=   1.0s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=2, min_samples_split=10; total time=   1.1s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=2, min_samples_split=10; total time=   1.5s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=2, min_samples_split=10; total time=   1.5s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=4, min_samples_split=2; total time=   1.5s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=4, min_samples_split=2; total time=   1.6s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=4, min_samples_split=2; total time=   1.8s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=4, min_samples_split=2; total time=   1.5s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=4, min_samples_split=2; total time=   1.4s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=4, min_samples_split=5; total time=   1.4s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=4, min_samples_split=5; total time=   1.3s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=4, min_samples_split=5; total time=   1.3s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=4, min_samples_split=5; total time=   1.0s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=4, min_samples_split=5; total time=   1.0s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=4, min_samples_split=10; total time=   0.9s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=4, min_samples_split=10; total time=   0.9s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=4, min_samples_split=10; total time=   0.9s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=4, min_samples_split=10; total time=   0.9s
# [CV] END criterion=entropy, max_depth=7, min_samples_leaf=4, min_samples_split=10; total time=   0.9s
# [CV] END criterion=entropy, max_depth=9, min_samples_leaf=1, min_samples_split=2; total time=   1.0s
# [CV] END criterion=entropy, max_depth=9, min_samples_leaf=1, min_samples_split=2; total time=   1.1s
# [CV] END criterion=entropy, max_depth=9, min_samples_leaf=1, min_samples_split=2; total time=   1.1s
# [CV] END criterion=entropy, max_depth=9, min_samples_leaf=1, min_samples_split=2; total time=   1.1s
# [CV] END criterion=entropy, max_depth=9, min_samples_leaf=1, min_samples_split=2; total time=   1.1s
# [CV] END criterion=entropy, max_depth=9, min_samples_leaf=1, min_samples_split=5; total time=   1.1s
# [CV] END criterion=entropy, max_depth=9, min_samples_leaf=1, min_samples_split=5; total time=   1.1s
# [CV] END criterion=entropy, max_depth=9, min_samples_leaf=1, min_samples_split=5; total time=   1.1s
# [CV] END criterion=entropy, max_depth=9, min_samples_leaf=1, min_samples_split=5; total time=   1.1s
# [CV] END criterion=entropy, max_depth=9, min_samples_leaf=1, min_samples_split=5; total time=   1.2s
# [CV] END criterion=entropy, max_depth=9, min_samples_leaf=1, min_samples_split=10; total time=   1.1s
# [CV] END criterion=entropy, max_depth=9, min_samples_leaf=1, min_samples_split=10; total time=   1.1s
# [CV] END criterion=entropy, max_depth=9, min_samples_leaf=1, min_samples_split=10; total time=   1.2s
# [CV] END criterion=entropy, max_depth=9, min_samples_leaf=1, min_samples_split=10; total time=   1.1s
# [CV] END criterion=entropy, max_depth=9, min_samples_leaf=1, min_samples_split=10; total time=   1.1s
# [CV] END criterion=entropy, max_depth=9, min_samples_leaf=2, min_samples_split=2; total time=   1.1s
# [CV] END criterion=entropy, max_depth=9, min_samples_leaf=2, min_samples_split=2; total time=   1.1s
# [CV] END criterion=entropy, max_depth=9, min_samples_leaf=2, min_samples_split=2; total time=   1.3s
# [CV] END criterion=entropy, max_depth=9, min_samples_leaf=2, min_samples_split=2; total time=   1.1s
# [CV] END criterion=entropy, max_depth=9, min_samples_leaf=2, min_samples_split=2; total time=   1.0s
# [CV] END criterion=entropy, max_depth=9, min_samples_leaf=2, min_samples_split=5; total time=   1.1s
# [CV] END criterion=entropy, max_depth=9, min_samples_leaf=2, min_samples_split=5; total time=   1.4s
# [CV] END criterion=entropy, max_depth=9, min_samples_leaf=2, min_samples_split=5; total time=   1.6s
# [CV] END criterion=entropy, max_depth=9, min_samples_leaf=2, min_samples_split=5; total time=   1.6s
# [CV] END criterion=entropy, max_depth=9, min_samples_leaf=2, min_samples_split=5; total time=   1.6s
# [CV] END criterion=entropy, max_depth=9, min_samples_leaf=2, min_samples_split=10; total time=   1.6s
# [CV] END criterion=entropy, max_depth=9, min_samples_leaf=2, min_samples_split=10; total time=   1.6s
# [CV] END criterion=entropy, max_depth=9, min_samples_leaf=2, min_samples_split=10; total time=   1.7s
# [CV] END criterion=entropy, max_depth=9, min_samples_leaf=2, min_samples_split=10; total time=   1.4s
# [CV] END criterion=entropy, max_depth=9, min_samples_leaf=2, min_samples_split=10; total time=   1.3s
# [CV] END criterion=entropy, max_depth=9, min_samples_leaf=4, min_samples_split=2; total time=   1.4s
# [CV] END criterion=entropy, max_depth=9, min_samples_leaf=4, min_samples_split=2; total time=   1.1s
# [CV] END criterion=entropy, max_depth=9, min_samples_leaf=4, min_samples_split=2; total time=   1.5s
# [CV] END criterion=entropy, max_depth=9, min_samples_leaf=4, min_samples_split=2; total time=   1.1s
# [CV] END criterion=entropy, max_depth=9, min_samples_leaf=4, min_samples_split=2; total time=   1.1s
# [CV] END criterion=entropy, max_depth=9, min_samples_leaf=4, min_samples_split=5; total time=   1.1s
# [CV] END criterion=entropy, max_depth=9, min_samples_leaf=4, min_samples_split=5; total time=   1.1s
# [CV] END criterion=entropy, max_depth=9, min_samples_leaf=4, min_samples_split=5; total time=   1.1s
# [CV] END criterion=entropy, max_depth=9, min_samples_leaf=4, min_samples_split=5; total time=   1.2s
# [CV] END criterion=entropy, max_depth=9, min_samples_leaf=4, min_samples_split=5; total time=   1.3s
# [CV] END criterion=entropy, max_depth=9, min_samples_leaf=4, min_samples_split=10; total time=   1.2s
# [CV] END criterion=entropy, max_depth=9, min_samples_leaf=4, min_samples_split=10; total time=   1.8s
# [CV] END criterion=entropy, max_depth=9, min_samples_leaf=4, min_samples_split=10; total time=   1.8s
# [CV] END criterion=entropy, max_depth=9, min_samples_leaf=4, min_samples_split=10; total time=   1.9s
# [CV] END criterion=entropy, max_depth=9, min_samples_leaf=4, min_samples_split=10; total time=   1.8s
# [CV] END criterion=entropy, max_depth=11, min_samples_leaf=1, min_samples_split=2; total time=   1.9s
# [CV] END criterion=entropy, max_depth=11, min_samples_leaf=1, min_samples_split=2; total time=   1.9s
# [CV] END criterion=entropy, max_depth=11, min_samples_leaf=1, min_samples_split=2; total time=   1.8s
# [CV] END criterion=entropy, max_depth=11, min_samples_leaf=1, min_samples_split=2; total time=   1.8s
# [CV] END criterion=entropy, max_depth=11, min_samples_leaf=1, min_samples_split=2; total time=   1.4s
# [CV] END criterion=entropy, max_depth=11, min_samples_leaf=1, min_samples_split=5; total time=   1.3s
# [CV] END criterion=entropy, max_depth=11, min_samples_leaf=1, min_samples_split=5; total time=   1.3s
# [CV] END criterion=entropy, max_depth=11, min_samples_leaf=1, min_samples_split=5; total time=   1.3s
# [CV] END criterion=entropy, max_depth=11, min_samples_leaf=1, min_samples_split=5; total time=   1.8s
# [CV] END criterion=entropy, max_depth=11, min_samples_leaf=1, min_samples_split=5; total time=   1.8s
# [CV] END criterion=entropy, max_depth=11, min_samples_leaf=1, min_samples_split=10; total time=   1.8s
# [CV] END criterion=entropy, max_depth=11, min_samples_leaf=1, min_samples_split=10; total time=   1.9s
# [CV] END criterion=entropy, max_depth=11, min_samples_leaf=1, min_samples_split=10; total time=   1.9s
# [CV] END criterion=entropy, max_depth=11, min_samples_leaf=1, min_samples_split=10; total time=   1.9s
# [CV] END criterion=entropy, max_depth=11, min_samples_leaf=1, min_samples_split=10; total time=   1.8s
# [CV] END criterion=entropy, max_depth=11, min_samples_leaf=2, min_samples_split=2; total time=   1.8s
# [CV] END criterion=entropy, max_depth=11, min_samples_leaf=2, min_samples_split=2; total time=   1.8s
# [CV] END criterion=entropy, max_depth=11, min_samples_leaf=2, min_samples_split=2; total time=   1.9s
# [CV] END criterion=entropy, max_depth=11, min_samples_leaf=2, min_samples_split=2; total time=   2.3s
# [CV] END criterion=entropy, max_depth=11, min_samples_leaf=2, min_samples_split=2; total time=   2.1s
# [CV] END criterion=entropy, max_depth=11, min_samples_leaf=2, min_samples_split=5; total time=   1.8s
# [CV] END criterion=entropy, max_depth=11, min_samples_leaf=2, min_samples_split=5; total time=   1.9s
# [CV] END criterion=entropy, max_depth=11, min_samples_leaf=2, min_samples_split=5; total time=   1.5s
# [CV] END criterion=entropy, max_depth=11, min_samples_leaf=2, min_samples_split=5; total time=   1.2s
# [CV] END criterion=entropy, max_depth=11, min_samples_leaf=2, min_samples_split=5; total time=   1.2s
# [CV] END criterion=entropy, max_depth=11, min_samples_leaf=2, min_samples_split=10; total time=   1.2s
# [CV] END criterion=entropy, max_depth=11, min_samples_leaf=2, min_samples_split=10; total time=   1.3s
# [CV] END criterion=entropy, max_depth=11, min_samples_leaf=2, min_samples_split=10; total time=   1.2s
# [CV] END criterion=entropy, max_depth=11, min_samples_leaf=2, min_samples_split=10; total time=   1.2s
# [CV] END criterion=entropy, max_depth=11, min_samples_leaf=2, min_samples_split=10; total time=   2.0s
# [CV] END criterion=entropy, max_depth=11, min_samples_leaf=4, min_samples_split=2; total time=   2.3s
# [CV] END criterion=entropy, max_depth=11, min_samples_leaf=4, min_samples_split=2; total time=   2.5s
# [CV] END criterion=entropy, max_depth=11, min_samples_leaf=4, min_samples_split=2; total time=   2.1s
# [CV] END criterion=entropy, max_depth=11, min_samples_leaf=4, min_samples_split=2; total time=   3.1s
# [CV] END criterion=entropy, max_depth=11, min_samples_leaf=4, min_samples_split=2; total time=   2.8s
# [CV] END criterion=entropy, max_depth=11, min_samples_leaf=4, min_samples_split=5; total time=   2.2s
# [CV] END criterion=entropy, max_depth=11, min_samples_leaf=4, min_samples_split=5; total time=   1.8s
# [CV] END criterion=entropy, max_depth=11, min_samples_leaf=4, min_samples_split=5; total time=   1.8s
# [CV] END criterion=entropy, max_depth=11, min_samples_leaf=4, min_samples_split=5; total time=   1.2s
# [CV] END criterion=entropy, max_depth=11, min_samples_leaf=4, min_samples_split=5; total time=   2.7s
# [CV] END criterion=entropy, max_depth=11, min_samples_leaf=4, min_samples_split=10; total time=   2.1s
# [CV] END criterion=entropy, max_depth=11, min_samples_leaf=4, min_samples_split=10; total time=   2.5s
# [CV] END criterion=entropy, max_depth=11, min_samples_leaf=4, min_samples_split=10; total time=   2.6s
# [CV] END criterion=entropy, max_depth=11, min_samples_leaf=4, min_samples_split=10; total time=   1.7s
# [CV] END criterion=entropy, max_depth=11, min_samples_leaf=4, min_samples_split=10; total time=   1.7s
# [CV] END criterion=entropy, max_depth=13, min_samples_leaf=1, min_samples_split=2; total time=   1.8s
# [CV] END criterion=entropy, max_depth=13, min_samples_leaf=1, min_samples_split=2; total time=   1.3s
# [CV] END criterion=entropy, max_depth=13, min_samples_leaf=1, min_samples_split=2; total time=   1.5s
# [CV] END criterion=entropy, max_depth=13, min_samples_leaf=1, min_samples_split=2; total time=   1.3s
# [CV] END criterion=entropy, max_depth=13, min_samples_leaf=1, min_samples_split=2; total time=   1.3s
# [CV] END criterion=entropy, max_depth=13, min_samples_leaf=1, min_samples_split=5; total time=   1.3s
# [CV] END criterion=entropy, max_depth=13, min_samples_leaf=1, min_samples_split=5; total time=   1.4s
# [CV] END criterion=entropy, max_depth=13, min_samples_leaf=1, min_samples_split=5; total time=   1.3s
# [CV] END criterion=entropy, max_depth=13, min_samples_leaf=1, min_samples_split=5; total time=   1.3s
# [CV] END criterion=entropy, max_depth=13, min_samples_leaf=1, min_samples_split=5; total time=   1.3s
# [CV] END criterion=entropy, max_depth=13, min_samples_leaf=1, min_samples_split=10; total time=   1.3s
# [CV] END criterion=entropy, max_depth=13, min_samples_leaf=1, min_samples_split=10; total time=   2.0s
# [CV] END criterion=entropy, max_depth=13, min_samples_leaf=1, min_samples_split=10; total time=   3.4s
# [CV] END criterion=entropy, max_depth=13, min_samples_leaf=1, min_samples_split=10; total time=   3.4s
# [CV] END criterion=entropy, max_depth=13, min_samples_leaf=1, min_samples_split=10; total time=   1.9s
# [CV] END criterion=entropy, max_depth=13, min_samples_leaf=2, min_samples_split=2; total time=   1.8s
# [CV] END criterion=entropy, max_depth=13, min_samples_leaf=2, min_samples_split=2; total time=   1.4s
# [CV] END criterion=entropy, max_depth=13, min_samples_leaf=2, min_samples_split=2; total time=   1.4s
# [CV] END criterion=entropy, max_depth=13, min_samples_leaf=2, min_samples_split=2; total time=   1.5s
# [CV] END criterion=entropy, max_depth=13, min_samples_leaf=2, min_samples_split=2; total time=   1.5s
# [CV] END criterion=entropy, max_depth=13, min_samples_leaf=2, min_samples_split=5; total time=   1.3s
# [CV] END criterion=entropy, max_depth=13, min_samples_leaf=2, min_samples_split=5; total time=   1.4s
# [CV] END criterion=entropy, max_depth=13, min_samples_leaf=2, min_samples_split=5; total time=   2.0s
# [CV] END criterion=entropy, max_depth=13, min_samples_leaf=2, min_samples_split=5; total time=   2.2s
# [CV] END criterion=entropy, max_depth=13, min_samples_leaf=2, min_samples_split=5; total time=   2.4s
# [CV] END criterion=entropy, max_depth=13, min_samples_leaf=2, min_samples_split=10; total time=   2.7s
# [CV] END criterion=entropy, max_depth=13, min_samples_leaf=2, min_samples_split=10; total time=   1.9s
# [CV] END criterion=entropy, max_depth=13, min_samples_leaf=2, min_samples_split=10; total time=   2.3s
# [CV] END criterion=entropy, max_depth=13, min_samples_leaf=2, min_samples_split=10; total time=   2.8s
# ...
# [CV] END criterion=ratio, max_depth=11, min_samples_leaf=1, min_samples_split=10; total time=   0.0s
# [CV] END criterion=ratio, max_depth=11, min_samples_leaf=1, min_samples_split=10; total time=   0.0s
# [CV] END criterion=ratio, max_depth=11, min_samples_leaf=1, min_samples_split=10; total time=   0.0s
# [CV] END criterion=ratio, max_depth=11, min_samples_leaf=1, min_samples_split=10; total time=   0.0s
# [CV] END criterion=ratio, max_depth=11, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END criterion=ratio, max_depth=11, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END criterion=ratio, max_depth=11, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END criterion=ratio, max_depth=11, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END criterion=ratio, max_depth=11, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END criterion=ratio, max_depth=11, min_samples_leaf=2, min_samples_split=5; total time=   0.0s
# [CV] END criterion=ratio, max_depth=11, min_samples_leaf=2, min_samples_split=5; total time=   0.0s
# [CV] END criterion=ratio, max_depth=11, min_samples_leaf=2, min_samples_split=5; total time=   0.0s
# [CV] END criterion=ratio, max_depth=11, min_samples_leaf=2, min_samples_split=5; total time=   0.0s
# [CV] END criterion=ratio, max_depth=11, min_samples_leaf=2, min_samples_split=5; total time=   0.0s
# [CV] END criterion=ratio, max_depth=11, min_samples_leaf=2, min_samples_split=10; total time=   0.0s
# [CV] END criterion=ratio, max_depth=11, min_samples_leaf=2, min_samples_split=10; total time=   0.0s
# [CV] END criterion=ratio, max_depth=11, min_samples_leaf=2, min_samples_split=10; total time=   0.0s
# [CV] END criterion=ratio, max_depth=11, min_samples_leaf=2, min_samples_split=10; total time=   0.0s
# [CV] END criterion=ratio, max_depth=11, min_samples_leaf=2, min_samples_split=10; total time=   0.0s
# [CV] END criterion=ratio, max_depth=11, min_samples_leaf=4, min_samples_split=2; total time=   0.0s
# [CV] END criterion=ratio, max_depth=11, min_samples_leaf=4, min_samples_split=2; total time=   0.0s
# [CV] END criterion=ratio, max_depth=11, min_samples_leaf=4, min_samples_split=2; total time=   0.0s
# [CV] END criterion=ratio, max_depth=11, min_samples_leaf=4, min_samples_split=2; total time=   0.0s
# [CV] END criterion=ratio, max_depth=11, min_samples_leaf=4, min_samples_split=2; total time=   0.0s
# [CV] END criterion=ratio, max_depth=11, min_samples_leaf=4, min_samples_split=5; total time=   0.0s
# [CV] END criterion=ratio, max_depth=11, min_samples_leaf=4, min_samples_split=5; total time=   0.0s
# [CV] END criterion=ratio, max_depth=11, min_samples_leaf=4, min_samples_split=5; total time=   0.0s
# [CV] END criterion=ratio, max_depth=11, min_samples_leaf=4, min_samples_split=5; total time=   0.0s
# [CV] END criterion=ratio, max_depth=11, min_samples_leaf=4, min_samples_split=5; total time=   0.0s
# [CV] END criterion=ratio, max_depth=11, min_samples_leaf=4, min_samples_split=10; total time=   0.0s
# [CV] END criterion=ratio, max_depth=11, min_samples_leaf=4, min_samples_split=10; total time=   0.0s
# [CV] END criterion=ratio, max_depth=11, min_samples_leaf=4, min_samples_split=10; total time=   0.0s
# [CV] END criterion=ratio, max_depth=11, min_samples_leaf=4, min_samples_split=10; total time=   0.0s
# [CV] END criterion=ratio, max_depth=11, min_samples_leaf=4, min_samples_split=10; total time=   0.0s
# [CV] END criterion=ratio, max_depth=13, min_samples_leaf=1, min_samples_split=2; total time=   0.0s
# [CV] END criterion=ratio, max_depth=13, min_samples_leaf=1, min_samples_split=2; total time=   0.0s
# [CV] END criterion=ratio, max_depth=13, min_samples_leaf=1, min_samples_split=2; total time=   0.0s
# [CV] END criterion=ratio, max_depth=13, min_samples_leaf=1, min_samples_split=2; total time=   0.0s
# [CV] END criterion=ratio, max_depth=13, min_samples_leaf=1, min_samples_split=2; total time=   0.0s
# [CV] END criterion=ratio, max_depth=13, min_samples_leaf=1, min_samples_split=5; total time=   0.0s
# [CV] END criterion=ratio, max_depth=13, min_samples_leaf=1, min_samples_split=5; total time=   0.0s
# [CV] END criterion=ratio, max_depth=13, min_samples_leaf=1, min_samples_split=5; total time=   0.0s
# [CV] END criterion=ratio, max_depth=13, min_samples_leaf=1, min_samples_split=5; total time=   0.0s
# [CV] END criterion=ratio, max_depth=13, min_samples_leaf=1, min_samples_split=5; total time=   0.0s
# [CV] END criterion=ratio, max_depth=13, min_samples_leaf=1, min_samples_split=10; total time=   0.0s
# [CV] END criterion=ratio, max_depth=13, min_samples_leaf=1, min_samples_split=10; total time=   0.0s
# [CV] END criterion=ratio, max_depth=13, min_samples_leaf=1, min_samples_split=10; total time=   0.0s
# [CV] END criterion=ratio, max_depth=13, min_samples_leaf=1, min_samples_split=10; total time=   0.0s
# [CV] END criterion=ratio, max_depth=13, min_samples_leaf=1, min_samples_split=10; total time=   0.0s
# [CV] END criterion=ratio, max_depth=13, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END criterion=ratio, max_depth=13, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END criterion=ratio, max_depth=13, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END criterion=ratio, max_depth=13, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END criterion=ratio, max_depth=13, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END criterion=ratio, max_depth=13, min_samples_leaf=2, min_samples_split=5; total time=   0.0s
# [CV] END criterion=ratio, max_depth=13, min_samples_leaf=2, min_samples_split=5; total time=   0.0s
# [CV] END criterion=ratio, max_depth=13, min_samples_leaf=2, min_samples_split=5; total time=   0.0s
# [CV] END criterion=ratio, max_depth=13, min_samples_leaf=2, min_samples_split=5; total time=   0.0s
# [CV] END criterion=ratio, max_depth=13, min_samples_leaf=2, min_samples_split=5; total time=   0.0s
# [CV] END criterion=ratio, max_depth=13, min_samples_leaf=2, min_samples_split=10; total time=   0.0s
# [CV] END criterion=ratio, max_depth=13, min_samples_leaf=2, min_samples_split=10; total time=   0.0s
# [CV] END criterion=ratio, max_depth=13, min_samples_leaf=2, min_samples_split=10; total time=   0.0s
# [CV] END criterion=ratio, max_depth=13, min_samples_leaf=2, min_samples_split=10; total time=   0.0s
# [CV] END criterion=ratio, max_depth=13, min_samples_leaf=2, min_samples_split=10; total time=   0.0s
# [CV] END criterion=ratio, max_depth=13, min_samples_leaf=4, min_samples_split=2; total time=   0.0s
# [CV] END criterion=ratio, max_depth=13, min_samples_leaf=4, min_samples_split=2; total time=   0.0s
# [CV] END criterion=ratio, max_depth=13, min_samples_leaf=4, min_samples_split=2; total time=   0.0s
# [CV] END criterion=ratio, max_depth=13, min_samples_leaf=4, min_samples_split=2; total time=   0.0s
# [CV] END criterion=ratio, max_depth=13, min_samples_leaf=4, min_samples_split=2; total time=   0.0s
# [CV] END criterion=ratio, max_depth=13, min_samples_leaf=4, min_samples_split=5; total time=   0.0s
# [CV] END criterion=ratio, max_depth=13, min_samples_leaf=4, min_samples_split=5; total time=   0.0s
# [CV] END criterion=ratio, max_depth=13, min_samples_leaf=4, min_samples_split=5; total time=   0.0s
# [CV] END criterion=ratio, max_depth=13, min_samples_leaf=4, min_samples_split=5; total time=   0.0s
# [CV] END criterion=ratio, max_depth=13, min_samples_leaf=4, min_samples_split=5; total time=   0.0s
# [CV] END criterion=ratio, max_depth=13, min_samples_leaf=4, min_samples_split=10; total time=   0.0s
# [CV] END criterion=ratio, max_depth=13, min_samples_leaf=4, min_samples_split=10; total time=   0.0s
# [CV] END criterion=ratio, max_depth=13, min_samples_leaf=4, min_samples_split=10; total time=   0.0s
# [CV] END criterion=ratio, max_depth=13, min_samples_leaf=4, min_samples_split=10; total time=   0.0s
# [CV] END criterion=ratio, max_depth=13, min_samples_leaf=4, min_samples_split=10; total time=   0.0s
# [CV] END criterion=ratio, max_depth=15, min_samples_leaf=1, min_samples_split=2; total time=   0.0s
# [CV] END criterion=ratio, max_depth=15, min_samples_leaf=1, min_samples_split=2; total time=   0.0s
# [CV] END criterion=ratio, max_depth=15, min_samples_leaf=1, min_samples_split=2; total time=   0.0s
# [CV] END criterion=ratio, max_depth=15, min_samples_leaf=1, min_samples_split=2; total time=   0.0s
# [CV] END criterion=ratio, max_depth=15, min_samples_leaf=1, min_samples_split=2; total time=   0.0s
# [CV] END criterion=ratio, max_depth=15, min_samples_leaf=1, min_samples_split=5; total time=   0.0s
# [CV] END criterion=ratio, max_depth=15, min_samples_leaf=1, min_samples_split=5; total time=   0.0s
# [CV] END criterion=ratio, max_depth=15, min_samples_leaf=1, min_samples_split=5; total time=   0.0s
# [CV] END criterion=ratio, max_depth=15, min_samples_leaf=1, min_samples_split=5; total time=   0.0s
# [CV] END criterion=ratio, max_depth=15, min_samples_leaf=1, min_samples_split=5; total time=   0.0s
# [CV] END criterion=ratio, max_depth=15, min_samples_leaf=1, min_samples_split=10; total time=   0.0s
# [CV] END criterion=ratio, max_depth=15, min_samples_leaf=1, min_samples_split=10; total time=   0.0s
# [CV] END criterion=ratio, max_depth=15, min_samples_leaf=1, min_samples_split=10; total time=   0.0s
# [CV] END criterion=ratio, max_depth=15, min_samples_leaf=1, min_samples_split=10; total time=   0.0s
# [CV] END criterion=ratio, max_depth=15, min_samples_leaf=1, min_samples_split=10; total time=   0.0s
# [CV] END criterion=ratio, max_depth=15, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END criterion=ratio, max_depth=15, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END criterion=ratio, max_depth=15, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END criterion=ratio, max_depth=15, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END criterion=ratio, max_depth=15, min_samples_leaf=2, min_samples_split=2; total time=   0.0s
# [CV] END criterion=ratio, max_depth=15, min_samples_leaf=2, min_samples_split=5; total time=   0.0s
# [CV] END criterion=ratio, max_depth=15, min_samples_leaf=2, min_samples_split=5; total time=   0.0s
# [CV] END criterion=ratio, max_depth=15, min_samples_leaf=2, min_samples_split=5; total time=   0.0s
# [CV] END criterion=ratio, max_depth=15, min_samples_leaf=2, min_samples_split=5; total time=   0.0s
# [CV] END criterion=ratio, max_depth=15, min_samples_leaf=2, min_samples_split=5; total time=   0.0s
# [CV] END criterion=ratio, max_depth=15, min_samples_leaf=2, min_samples_split=10; total time=   0.0s
# [CV] END criterion=ratio, max_depth=15, min_samples_leaf=2, min_samples_split=10; total time=   0.0s
# [CV] END criterion=ratio, max_depth=15, min_samples_leaf=2, min_samples_split=10; total time=   0.0s
# [CV] END criterion=ratio, max_depth=15, min_samples_leaf=2, min_samples_split=10; total time=   0.0s
# [CV] END criterion=ratio, max_depth=15, min_samples_leaf=2, min_samples_split=10; total time=   0.0s
# [CV] END criterion=ratio, max_depth=15, min_samples_leaf=4, min_samples_split=2; total time=   0.0s
# [CV] END criterion=ratio, max_depth=15, min_samples_leaf=4, min_samples_split=2; total time=   0.0s
# [CV] END criterion=ratio, max_depth=15, min_samples_leaf=4, min_samples_split=2; total time=   0.0s
# [CV] END criterion=ratio, max_depth=15, min_samples_leaf=4, min_samples_split=2; total time=   0.0s
# [CV] END criterion=ratio, max_depth=15, min_samples_leaf=4, min_samples_split=2; total time=   0.0s
# [CV] END criterion=ratio, max_depth=15, min_samples_leaf=4, min_samples_split=5; total time=   0.0s
# [CV] END criterion=ratio, max_depth=15, min_samples_leaf=4, min_samples_split=5; total time=   0.0s
# [CV] END criterion=ratio, max_depth=15, min_samples_leaf=4, min_samples_split=5; total time=   0.0s
# [CV] END criterion=ratio, max_depth=15, min_samples_leaf=4, min_samples_split=5; total time=   0.0s
# [CV] END criterion=ratio, max_depth=15, min_samples_leaf=4, min_samples_split=5; total time=   0.0s
# [CV] END criterion=ratio, max_depth=15, min_samples_leaf=4, min_samples_split=10; total time=   0.0s
# [CV] END criterion=ratio, max_depth=15, min_samples_leaf=4, min_samples_split=10; total time=   0.0s
# [CV] END criterion=ratio, max_depth=15, min_samples_leaf=4, min_samples_split=10; total time=   0.0s
# [CV] END criterion=ratio, max_depth=15, min_samples_leaf=4, min_samples_split=10; total time=   0.0s
# [CV] END criterion=ratio, max_depth=15, min_samples_leaf=4, min_samples_split=10; total time=   0.0s
# /home/goncalo/miniconda3/envs/daa310/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:425: FitFailedWarning:
# 270 fits failed out of a total of 810.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 270 fits failed with the following error:
# Traceback (most recent call last):
#   File "/home/goncalo/miniconda3/envs/daa310/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/home/goncalo/miniconda3/envs/daa310/lib/python3.10/site-packages/sklearn/base.py", line 1144, in wrapper
#     estimator._validate_params()
#   File "/home/goncalo/miniconda3/envs/daa310/lib/python3.10/site-packages/sklearn/base.py", line 637, in _validate_params
#     validate_parameter_constraints(
#   File "/home/goncalo/miniconda3/envs/daa310/lib/python3.10/site-packages/sklearn/utils/_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'criterion' parameter of RandomForestClassifier must be a str among {'gini', 'entropy', 'log_loss'}. Got 'ratio' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /home/goncalo/miniconda3/envs/daa310/lib/python3.10/site-packages/sklearn/model_selection/_search.py:976: UserWarning: One or more of the test scores are non-finite: [0.84558975 0.84667921 0.84595301 0.84785942 0.84722413 0.84568078
#  0.84577152 0.84577152 0.84540846 0.84822223 0.8498562  0.8499474
#  0.8500379  0.850401   0.85031046 0.8497655  0.8497655  0.85049174
#  0.8516722  0.85185364 0.85049186 0.85130881 0.85049178 0.85067352
#  0.85203525 0.85203525 0.84949335 0.85149075 0.84885826 0.85185377
#  0.85040161 0.85076438 0.85276178 0.84795    0.84795    0.85012885
#  0.84840409 0.85276183 0.84985682 0.85149071 0.85140005 0.85094583
#  0.85031046 0.85031046 0.8495843  0.84994769 0.85267071 0.85158178
#  0.85203525 0.85185377 0.85312476 0.85094579 0.85094579 0.84994748
#  0.84304846 0.8437747  0.84404706 0.84377462 0.84386553 0.8437747
#  0.84377482 0.84377482 0.843684   0.8507643  0.85149058 0.8501288
#  0.8515817  0.85031038 0.85067352 0.85085525 0.85085525 0.85049195
#  0.85112777 0.85376042 0.85103695 0.85149058 0.85457733 0.85076443
#  0.85085513 0.85085513 0.85012897 0.85194496 0.85149095 0.85230769
#  0.85394203 0.85185377 0.85076451 0.85221687 0.85221687 0.85403282
#  0.85167265 0.85684688 0.85430522 0.85294319 0.85285249 0.85357852
#  0.85258025 0.85258025 0.85112757 0.85149083 0.85212678 0.85294315
#  0.85140033 0.85003831 0.85130955 0.8512186  0.8512186  0.85439567
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan]
#   warnings.warn(

# %% [markdown]
# ### Treino do modelo

# %%
# model.fit(x, y)

# %% [markdown]
# ### Previsões do modelo

# %%
print(df.columns)
print(df_test.columns)
# Out:
# Index(['temp', 'feels_like', 'temp_min', 'temp_max', 'pressure', 'humidity',
#        'Hora', 'Normal (kWh)', 'Horário Económico (kWh)', 'Autoconsumo (kWh)',
#        'Injeção na rede (kWh)', 'weather_description_encoded'],
#       dtype='object')
# Index(['temp', 'feels_like', 'temp_min', 'temp_max', 'pressure', 'humidity',
#        'Hora', 'Normal (kWh)', 'Horário Económico (kWh)', 'Autoconsumo (kWh)',
#        'weather_description_encoded'],
#       dtype='object')

# %%
y_pred = model.predict(df_test)

# %% [markdown]
# ### Escrita em ficheiro csv

# %%
df_predicoes = pd.DataFrame({'Result': y_pred})
df_predicoes['RowId'] = range(1, len(y_pred) + 1)
df_predicoes = df_predicoes[['RowId', 'Result']]

df_predicoes.to_csv('../../datasets/parte2/teste/previsoesRandomForestTree.csv', index=False)
